# %% [markdown]
# <div style="display: flex; background-color: RGB(255,114,0);" >
#
# # PROJET - Bonheur World </h1>
# </div>

# %% [markdown]
# <div style="display: flex; background-color: Blue; padding: 15px;" >
#
# ## 1.Mission
# </div>
#
# Challenge goals
#
# How accurately can we predict regional temperature anomalies based on past and neighbouring climate observations ?

# %% [markdown]
# Dans cette étude de cas, nous formerons un algorithme d'apprentissage automatique non supervisé pour regrouper les pays en fonction de caractéristiques telles que la production économique, le soutien social, l'espérance de vie, la liberté, l'absence de corruption et la générosité. Le Rapport sur le bonheur dans le monde détermine l'état du bonheur mondial. Les scores de bonheur et les données de classement ont été collectés en demandant aux individus de classer leur vie de 0 (la pire vie possible) à 10 (la meilleure vie possible).
#
# - Un notebook contenant les fonctions permettant le prétraitement des données ainsi que les résultats du clustering (en y incluant des représentations graphiques) ....
# - Un support de présentation qui présente la démarche et les résultats du clustering.

# %%
from os import getcwd
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno
from tqdm import tqdm
from bonheur_bed_ara import *
from IPython.core.display import HTML

# %% [markdown]
# <div style="display: flex; background-color: Blue; padding: 15px;" >
#
# ## 2.Chargement des données
# </div>

# %%
# ---------------------------------------------------------------------------------------------
#                               MAIN
# ---------------------------------------------------------------------------------------------
verbose = False
force_reloading = True

# Récupère le répertoire du programme
file_path = getcwd() + "\\"
data_set_path = file_path + "dataset\\"
country_col_name = "country"
country_official_col_name = "country_official"

print(f"Current execution path : {file_path}")
print(f"Dataset path : {data_set_path}")
# Out:
# Current execution path : c:\Users\User\WORK\workspace-ia\PROJETS\projet_bonheur_bed\
# Dataset path : c:\Users\User\WORK\workspace-ia\PROJETS\projet_bonheur_bed\dataset\

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 2.1. Données pays
# </div>

# %%
pays_file_name = "data_set_countries_clean.csv"

df_pays_origin = pd.read_csv(data_set_path+pays_file_name, sep=',')
df_pays_origin = df_pays_origin.sort_values(by=country_col_name)
df_pays_origin["id"] = df_pays_origin["id"].fillna(-1)
df_pays_origin["id"] = df_pays_origin["id"].astype(int)
df_pays_origin = df_pays_origin.reset_index()
df_pays_origin = df_pays_origin.drop("index", axis=1)

print(f"{df_pays_origin.shape} données chargées ------> {list(df_pays_origin.columns)}")
df_pays_origin.head()
# Out:
# (213, 8) données chargées ------> ['id', 'alpha3', 'alpha2', 'country', 'country_official', 'continent_code', 'latitude', 'longitude']
#    id alpha3 alpha2      country                         country_official  \
# 0   4    AFG     AF  Afghanistan          Islamic Republic of Afghanistan
# 1   8    ALB     AL      Albania                      Republic of Albania
# 2  12    DZA     DZ      Algeria  People's Democratic Republic of Algeria
# 3  24    AGO     AO       Angola                       Republic of Angola
# 4  10    ATA     AQ   Antarctica                               Antarctica
#
#   continent_code   latitude  longitude
# 0             AS  29.276770  42.274721
# 1             EU  21.483333  36.066667
# 2             AF  14.349729  43.892024
# 3             AF  41.795972  12.235112
# 4            NaN -22.016981 -47.920533

# %%
df_pays_origin.dtypes
# Out:
# id                    int32
# alpha3               object
# alpha2               object
# country              object
# country_official     object
# continent_code       object
# latitude            float64
# longitude           float64
# dtype: object

# %%
df_pays_origin.describe(include="all")
# Out:
#                 id alpha3 alpha2      country  \
# count   213.000000    213    212          213
# unique         NaN    213    212          213
# top            NaN    AFG     AF  Afghanistan
# freq           NaN      1      1            1
# mean    338.938967    NaN    NaN          NaN
# std     281.280111    NaN    NaN          NaN
# min      -1.000000    NaN    NaN          NaN
# 25%      56.000000    NaN    NaN          NaN
# 50%     320.000000    NaN    NaN          NaN
# 75%     578.000000    NaN    NaN          NaN
# max     894.000000    NaN    NaN          NaN
#
#                        country_official continent_code    latitude   longitude
# count                               213            182  194.000000  194.000000
# unique                              213              5         NaN         NaN
# top     Islamic Republic of Afghanistan             AF         NaN         NaN
# freq                                  1             56         NaN         NaN
# mean                                NaN            NaN   25.128428   19.543371
# std                                 NaN            NaN   24.780335   60.798641
# min                                 NaN            NaN  -41.333167 -149.400973
# 25%                                 NaN            NaN   13.297541   -1.755094
# 50%                                 NaN            NaN   32.815291   18.894266
# 75%                                 NaN            NaN   45.811730   45.827753
# max                                 NaN            NaN   61.924110  174.807770

# %%
df_pays_origin[df_pays_origin["alpha2"].duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, alpha3, alpha2, country, country_official, continent_code, latitude, longitude]
# Index: []

# %%
# correction des doublons
df_pays_origin.loc[df_pays_origin["alpha3"]=="NAM", "alpha2"] = "NA"
df_pays_origin = df_pays_origin.drop_duplicates(subset=["alpha2"], keep="first")
print(df_pays_origin[df_pays_origin["alpha2"].duplicated()].shape)
df_pays_origin[(df_pays_origin["alpha2"]=="SO") | (df_pays_origin["alpha2"]=="CY")| (df_pays_origin["alpha3"]=="NAM")]
# Out:
# (0, 8)
#       id alpha3 alpha2  country             country_official continent_code  \
# 41   196    CYP     CY   Cyprus           Republic of Cyprus             AS
# 125  516    NAM     NA  Namibia          Republic of Namibia             AF
# 171  706    SOM     SO  Somalia  Federal Republic of Somalia             AF
#
#       latitude  longitude
# 41   34.683875  32.605168
# 125  34.530234  69.230180
# 171  11.795646  41.012891

# %%
df_pays_origin[df_pays_origin["alpha3"].duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, alpha3, alpha2, country, country_official, continent_code, latitude, longitude]
# Index: []

# %%
print(df_pays_origin[df_pays_origin["alpha3"].duplicated()].shape)
df_pays_origin[df_pays_origin["alpha3"]=="-99"]
# Out:
# (0, 8)
# Empty DataFrame
# Columns: [id, alpha3, alpha2, country, country_official, continent_code, latitude, longitude]
# Index: []

# %%
df_pays_origin.loc[df_pays_origin["alpha3"]=="-99", "alpha3"] = np.nan
print(df_pays_origin[df_pays_origin["alpha3"].duplicated()].shape)
df_pays_origin[df_pays_origin["alpha3"].duplicated()]
# Out:
# (0, 8)
# Empty DataFrame
# Columns: [id, alpha3, alpha2, country, country_official, continent_code, latitude, longitude]
# Index: []

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 2.1.3 Visualisation
# </div>

# %%
df_pays_origin = df_pays_origin.rename(columns={"id":"id_country"})
df_pays_origin.columns
# Out:
# Index(['id_country', 'alpha3', 'alpha2', 'country', 'country_official',
#        'continent_code', 'latitude', 'longitude'],
#       dtype='object')

# %%
print(df_pays_origin.shape)
df_pays_origin.describe(include="all")
# Out:
# (213, 8)
#         id_country alpha3 alpha2      country  \
# count   213.000000    213    213          213
# unique         NaN    213    213          213
# top            NaN    AFG     AF  Afghanistan
# freq           NaN      1      1            1
# mean    338.938967    NaN    NaN          NaN
# std     281.280111    NaN    NaN          NaN
# min      -1.000000    NaN    NaN          NaN
# 25%      56.000000    NaN    NaN          NaN
# 50%     320.000000    NaN    NaN          NaN
# 75%     578.000000    NaN    NaN          NaN
# max     894.000000    NaN    NaN          NaN
#
#                        country_official continent_code    latitude   longitude
# count                               213            182  194.000000  194.000000
# unique                              213              5         NaN         NaN
# top     Islamic Republic of Afghanistan             AF         NaN         NaN
# freq                                  1             56         NaN         NaN
# mean                                NaN            NaN   25.128428   19.543371
# std                                 NaN            NaN   24.780335   60.798641
# min                                 NaN            NaN  -41.333167 -149.400973
# 25%                                 NaN            NaN   13.297541   -1.755094
# 50%                                 NaN            NaN   32.815291   18.894266
# 75%                                 NaN            NaN   45.811730   45.827753
# max                                 NaN            NaN   61.924110  174.807770

# %%
figure, ax = color_graph_background(1,1)
sns.heatmap(df_pays_origin.isnull(), yticklabels=False,cbar=False, cmap='viridis')
plt.xticks(rotation=45, ha="right", fontsize=10)
plt.title("NA dans la DF PAYS")
figure.set_size_inches(18, 5, forward=True)
plt.show()

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 2.2. Evolution des scores
# </div>

# %%
data_evolution_name = "evolution_score_altasocio_2022-04-01.csv"
df_evolution_orgin = pd.read_csv(data_set_path+data_evolution_name, sep=',')
df_evolution_orgin = df_evolution_orgin.rename(columns={"pays":country_col_name})
df_evolution_orgin = df_evolution_orgin.sort_values(by=country_col_name)

# correction des types
df_evolution_orgin = df_correct_type_to_float(df_evolution_orgin, exclude_cols=[country_col_name])

print(f"{df_evolution_orgin.shape} données chargées ------> {list(df_evolution_orgin.columns)}")
df_evolution_orgin.head()
# Out:
# (165, 8) données chargées ------> ['country', 'score_2015', 'score_2016', 'score_2017', 'score_2018', 'score_2019', 'score_2020', 'country_official']
#             country  score_2015  score_2016  score_2017  score_2018  \
# 164     Afghanistan       3.575       3.360       3.794       3.632
# 115  Afrique du Sud       4.642       4.459       4.829       4.724
# 111         Albanie       4.959       4.655       4.644       4.586
# 106         Algérie       5.605       6.355       5.872       5.295
# 16        Allemagne       6.750       6.994       6.951       6.965
#
#      score_2019  score_2020                         country_official
# 164       3.203       2.567          Islamic Republic of Afghanistan
# 115       4.722       4.814                 Republic of South Africa
# 111       4.719       4.883                      Republic of Albania
# 106       5.211       5.005  People's Democratic Republic of Algeria
# 16        6.985       7.076              Federal Republic of Germany

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 2.1.2 Visualisation
# </div>

# %%
df_evolution_orgin.head()
# Out:
#             country  score_2015  score_2016  score_2017  score_2018  \
# 164     Afghanistan       3.575       3.360       3.794       3.632
# 115  Afrique du Sud       4.642       4.459       4.829       4.724
# 111         Albanie       4.959       4.655       4.644       4.586
# 106         Algérie       5.605       6.355       5.872       5.295
# 16        Allemagne       6.750       6.994       6.951       6.965
#
#      score_2019  score_2020                         country_official
# 164       3.203       2.567          Islamic Republic of Afghanistan
# 115       4.722       4.814                 Republic of South Africa
# 111       4.719       4.883                      Republic of Albania
# 106       5.211       5.005  People's Democratic Republic of Algeria
# 16        6.985       7.076              Federal Republic of Germany

# %%
df_evolution_orgin = df_evolution_orgin.rename(columns={"pays":"country"})
df_evolution_orgin.columns
# Out:
# Index(['country', 'score_2015', 'score_2016', 'score_2017', 'score_2018',
#        'score_2019', 'score_2020', 'country_official'],
#       dtype='object')

# %%
df_evolution_orgin.describe(include="all")
# Out:
#             country  score_2015  score_2016  score_2017  score_2018  \
# count           165  158.000000  157.000000  155.000000  156.000000
# unique          165         NaN         NaN         NaN         NaN
# top     Afghanistan         NaN         NaN         NaN         NaN
# freq              1         NaN         NaN         NaN         NaN
# mean            NaN    5.375778    5.382185    5.367619    5.375917
# std             NaN    1.144889    1.141674    1.142394    1.119506
# min             NaN    2.839000    2.905000    2.693000    2.905000
# 25%             NaN    4.526000    4.404000    4.505500    4.453750
# 50%             NaN    5.232500    5.314000    5.293000    5.378000
# 75%             NaN    6.243750    6.269000    6.136500    6.168500
# max             NaN    7.587000    7.526000    7.537000    7.632000
#
#         score_2019  score_2020             country_official
# count   156.000000  153.000000                          165
# unique         NaN         NaN                          162
# top            NaN         NaN  Federal Republic of Somalia
# freq           NaN         NaN                            2
# mean      5.407032    5.473255                          NaN
# std       1.113085    1.112288                          NaN
# min       2.853000    2.567000                          NaN
# 25%       4.544500    4.724000                          NaN
# 50%       5.379500    5.515000                          NaN
# 75%       6.184500    6.228000                          NaN
# max       7.769000    7.809000                          NaN

# %%
df_evolution_orgin.dtypes
# Out:
# country              object
# score_2015          float64
# score_2016          float64
# score_2017          float64
# score_2018          float64
# score_2019          float64
# score_2020          float64
# country_official     object
# dtype: object

# %%
figure, ax = color_graph_background(1,1)
sns.heatmap(df_evolution_orgin.isnull(), yticklabels=False,cbar=False, cmap='viridis')
plt.xticks(rotation=45, ha="right", fontsize=10)
plt.title("NA dans la DF historique des scores")
figure.set_size_inches(18, 5, forward=True)
plt.show()

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 2.3. Détails des scores
# </div>

# %%
score_dataset_filenames = []
score_rapport_with ="Rapport-bonheur-"

world_datas_files = []
world_start_with ="world_"

# récupération données
extensions = [".csv"]

for ext in extensions:
    score_dataset_filenames.extend(get_dir_files(data_set_path, start_with=score_rapport_with , endwith=ext))
    world_datas_files.extend(get_dir_files(data_set_path, start_with=world_start_with , endwith=ext))

print(f"{len(score_dataset_filenames)} Fichiers score à traiter et {len(world_datas_files)} Fichiers monde à traiter")
# Out:
# 4 Fichiers score à traiter et 20 Fichiers monde à traiter

# %%
# verbose = 1
df_origine_light, df_origine_by_line, df_origine = load_scores_files(score_dataset_filenames, data_set_path, country_col_name = country_col_name,country_official_name = country_official_col_name, score_rapport_with=score_rapport_with, verbose=verbose)
df_origine_light.head()
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 52.52it/s]
#          country_official            Regional indicator 2019-country_origin  \
# 0  Arab Republic of Egypt  Middle East and North Africa               Egypt
# 1      Argentine Republic   Latin America and Caribbean           Argentina
# 2               Australia         North America and ANZ           Australia
# 3                 Bolivia   Latin America and Caribbean             Bolivia
# 4            Burkina Faso            Sub-Saharan Africa        Burkina Faso
#
#   2020-country_origin 2021-country_origin 2022-country_origin  2019-country  \
# 0               Egypt               Egypt               Egypt         Egypt
# 1           Argentina           Argentina           Argentina     Argentina
# 2           Australia           Australia           Australia     Australia
# 3             Bolivia             Bolivia             Bolivia       Bolivia
# 4        Burkina Faso        Burkina Faso        Burkina Faso  Burkina Faso
#
#    2019-rank   2022   2021  ...  2022-rank  2022-Whisker-high  \
# 0      137.0  4.288  4.283  ...      129.0              4.377
# 1       47.0  5.967  5.929  ...       57.0              6.090
# 2       11.0  7.162  7.183  ...       12.0              7.244
# 3       61.0  5.600  5.716  ...       71.0              5.709
# 4      115.0  4.670  4.834  ...      113.0              4.814
#
#    2022-Whisker-low  2022-Dystopia + residual  2022-PIB  2022-Soutien  \
# 0             4.198                     0.856     1.388         0.732
# 1             5.844                     1.891     1.592         1.102
# 2             7.081                     2.011     1.900         1.203
# 3             5.491                     2.107     1.256         0.880
# 4             4.527                     2.313     0.779         0.565
#
#    2022-Esperance vie BS  2022-Liberte des choix de vie 2022-Generosite  \
# 0                  0.548                          0.469           0.041
# 1                  0.662                          0.555           0.081
# 2                  0.772                          0.676           0.258
# 3                  0.555                          0.627           0.112
# 4                  0.320                          0.382           0.186
#
#    2022-Corruption
# 0            0.254
# 1            0.085
# 2            0.341
# 3            0.064
# 4            0.126
#
# [5 rows x 49 columns]

# %%
df_origine_light.columns
# Out:
# Index(['country_official', 'Regional indicator', '2019-country_origin',
#        '2020-country_origin', '2021-country_origin', '2022-country_origin',
#        '2019-country', '2019-rank', '2022', '2021', '2020', '2019', '2019-PIB',
#        '2019-Soutien', '2019-Esperance vie BS',
#        '2019-Liberte des choix de vie', '2019-Generosite', '2019-Corruption',
#        '2020-country', '2020-Whisker-high', '2020-Whisker-low', '2020-PIB',
#        '2020-Soutien', '2020-Esperance vie BS',
#        '2020-Liberte des choix de vie', '2020-Generosite', '2020-Corruption',
#        '2020-Dystopia + residual', '2021-country', '2021-Whisker-high',
#        '2021-Whisker-low', '2021-PIB', '2021-Soutien', '2021-Esperance vie BS',
#        '2021-Liberte des choix de vie', '2021-Generosite', '2021-Corruption',
#        '2021-Dystopia + residual', '2022-country', '2022-rank',
#        '2022-Whisker-high', '2022-Whisker-low', '2022-Dystopia + residual',
#        '2022-PIB', '2022-Soutien', '2022-Esperance vie BS',
#        '2022-Liberte des choix de vie', '2022-Generosite', '2022-Corruption'],
#       dtype='object')

# %%
df_origine_light["country_official"].value_counts()
# Out:
# Arab Republic of Egypt         1
# Republic of North Macedonia    1
# Republic of Mali               1
# Republic of Malta              1
# Republic of Mauritius          1
#                               ..
# Malaysia                       1
# Moldova                        1
# Mongolia                       1
# Montenegro                     1
# Vietnam                        1
# Name: country_official, Length: 157, dtype: int64

# %% [markdown]
# Les doublons ont été traités dans lors du chargement des données (`Republic of Cyprus` et `Kingdom of Sweden`)

# %% [markdown]
# - Une analyse des différences entre les noms de pays des différentes années a été faite pour uniformiser les données. (cf. annexe)
# - Puis une fusion et suppression des colonnes inutiles des pays par années (avant de supprimer une vérification a été faite pour identifier les écarts (cf. annexe)

# %%
start = 2019
end = 2022

# %%
df_origine_light_year_merged = merge_and_clean_country_by_year(df=df_origine_light, start=start, end=end, verbose=verbose)
print(f"BEFORE : {df_origine_light.shape} / AFTER : {df_origine_light_year_merged.shape}")
df_origine_light_year_merged.head()
# Out:
# country_origin na:3 and country na:3
# country_origin na:1 and country na:1
# country_origin na:1 and country na:1
# country_origin na:0 and country na:0
# 100%|██████████| 4/4 [00:00<00:00, 4000.29it/s]
# BEFORE : (157, 49) / AFTER : (157, 42)
#          country_official country_origin            Regional indicator   2019  \
# 0  Arab Republic of Egypt          Egypt  Middle East and North Africa  4.166
# 1      Argentine Republic      Argentina   Latin America and Caribbean  6.086
# 2               Australia      Australia         North America and ANZ  7.228
# 3                 Bolivia        Bolivia   Latin America and Caribbean  5.779
# 4            Burkina Faso   Burkina Faso            Sub-Saharan Africa  4.587
#
#     2020   2021   2022  2019-rank  2019-Soutien  2022-rank  ...  \
# 0  4.151  4.283  4.288      137.0         1.039      129.0  ...
# 1  5.975  5.929  5.967       47.0         1.432       57.0  ...
# 2  7.223  7.183  7.162       11.0         1.548       12.0  ...
# 3  5.747  5.716  5.600       61.0         1.209       71.0  ...
# 4  4.769  4.834  4.670      115.0         1.056      113.0  ...
#
#    2021-Corruption  2021-Dystopia + residual  2022-Whisker-high  \
# 0            0.795                     1.648              4.377
# 1            0.834                     2.461              6.090
# 2            0.442                     2.598              7.244
# 3            0.839                     2.805              5.709
# 4            0.748                     3.133              4.814
#
#    2022-Whisker-low  2022-Dystopia + residual  2022-Soutien  \
# 0             4.198                     0.856         0.732
# 1             5.844                     1.891         1.102
# 2             7.081                     2.011         1.203
# 3             5.491                     2.107         0.880
# 4             4.527                     2.313         0.565
#
#    2022-Esperance vie BS  2022-Liberte des choix de vie  2022-Generosite  \
# 0                  0.548                          0.469            0.041
# 1                  0.662                          0.555            0.081
# 2                  0.772                          0.676            0.258
# 3                  0.555                          0.627            0.112
# 4                  0.320                          0.382            0.186
#
#    2022-Corruption
# 0            0.254
# 1            0.085
# 2            0.341
# 3            0.064
# 4            0.126
#
# [5 rows x 42 columns]

# %%
df_origine_light_year_merged.describe(include="all")
# Out:
#               country_official country_origin  Regional indicator        2019  \
# count                      157            157                 151  154.000000
# unique                     157            157                  10         NaN
# top     Arab Republic of Egypt          Egypt  Sub-Saharan Africa         NaN
# freq                         1              1                  39         NaN
# mean                       NaN            NaN                 NaN    5.410708
# std                        NaN            NaN                 NaN    1.114996
# min                        NaN            NaN                 NaN    2.853000
# 25%                        NaN            NaN                 NaN    4.550750
# 50%                        NaN            NaN                 NaN    5.379500
# 75%                        NaN            NaN                 NaN    6.189500
# max                        NaN            NaN                 NaN    7.769000
#
#               2020        2021        2022   2019-rank  2019-Soutien  \
# count   151.000000  147.000000  145.000000  154.000000    154.000000
# unique         NaN         NaN         NaN         NaN           NaN
# top            NaN         NaN         NaN         NaN           NaN
# freq           NaN         NaN         NaN         NaN           NaN
# mean      5.460391    5.520367    5.548972   78.324675      1.209110
# std       1.109022    1.070520    1.089181   45.178496      0.301099
# min       2.567000    2.523000    2.404000    1.000000      0.000000
# 25%       4.700500    4.843000    4.888000   39.250000      1.055250
# 50%       5.510000    5.477000    5.559000   78.500000      1.275500
# 75%       6.227500    6.239000    6.309000  116.750000      1.453500
# max       7.809000    7.842000    7.821000  156.000000      1.624000
#
#          2022-rank  ...  2021-Corruption  2021-Dystopia + residual  \
# count   145.000000  ...       147.000000                147.000000
# unique         NaN  ...              NaN                       NaN
# top            NaN  ...              NaN                       NaN
# freq           NaN  ...              NaN                       NaN
# mean     73.724138  ...         0.731476                  2.433898
# std      42.350141  ...         0.175578                  0.537060
# min       1.000000  ...         0.082000                  0.648000
# 25%      37.000000  ...         0.677500                  2.143000
# 50%      74.000000  ...         0.787000                  2.509000
# 75%     110.000000  ...         0.846000                  2.794000
# max     146.000000  ...         0.939000                  3.482000
#
#         2022-Whisker-high  2022-Whisker-low  2022-Dystopia + residual  \
# count          145.000000        145.000000                145.000000
# unique                NaN               NaN                       NaN
# top                   NaN               NaN                       NaN
# freq                  NaN               NaN                       NaN
# mean             5.669131          5.428821                  1.830345
# std              1.067948          1.111736                  0.536555
# min              2.469000          2.339000                  0.187000
# 25%              4.999000          4.753000                  1.555000
# 50%              5.679000          5.439000                  1.894000
# 75%              6.460000          6.202000                  2.153000
# max              7.886000          7.756000                  2.844000
#
#         2022-Soutien  2022-Esperance vie BS  2022-Liberte des choix de vie  \
# count     145.000000             145.000000                     145.000000
# unique           NaN                    NaN                            NaN
# top              NaN                    NaN                            NaN
# freq             NaN                    NaN                            NaN
# mean        0.905841               0.584566                       0.517703
# std         0.281092               0.175873                       0.146250
# min         0.000000               0.000000                       0.000000
# 25%         0.732000               0.462000                       0.440000
# 50%         0.958000               0.620000                       0.545000
# 75%         1.116000               0.719000                       0.627000
# max         1.320000               0.942000                       0.740000
#
#         2022-Generosite  2022-Corruption
# count        145.000000       145.000000
# unique              NaN              NaN
# top                 NaN              NaN
# freq                NaN              NaN
# mean           0.147545         0.155421
# std            0.083061         0.127721
# min            0.000000         0.000000
# 25%            0.089000         0.069000
# 50%            0.134000         0.123000
# 75%            0.198000         0.200000
# max            0.468000         0.587000
#
# [11 rows x 42 columns]

# %%
figure, ax = color_graph_background(1,1)
sns.heatmap(df_origine_light_year_merged.isnull(), yticklabels=False,cbar=False, cmap='viridis')
plt.xticks(rotation=45, ha="right", fontsize=10)
plt.title("NA dans la DF scores")
figure.set_size_inches(18, 5, forward=True)
plt.show()

# %%
df_origine_by_line["year"] = df_origine_by_line["year"].astype(int)
df_origine_by_line.head()
# Out:
#            country_official    country   rank  score    PIB  Soutien  \
# 136  Arab Republic of Egypt      Egypt  137.0    NaN    NaN      NaN
# 131  Arab Republic of Egypt      Egypt    NaN  4.283  9.367    0.750
# 128  Arab Republic of Egypt      Egypt  129.0  4.288  1.388    0.732
# 137  Arab Republic of Egypt      Egypt    NaN  4.151  9.317    0.735
# 46       Argentine Republic  Argentina   47.0    NaN    NaN      NaN
#
#      Esperance vie BS  Liberte des choix de vie  Generosite  Corruption  \
# 136               NaN                       NaN         NaN         NaN
# 131            61.998                     0.749      -0.182       0.795
# 128             0.548                     0.469       0.041       0.254
# 137            61.780                     0.708      -0.197       0.788
# 46                NaN                       NaN         NaN         NaN
#
#     country_origin  year            Regional indicator  Whisker-high  \
# 136          Egypt  2019                           NaN           NaN
# 131          Egypt  2021  Middle East and North Africa         4.371
# 128          Egypt  2022                           NaN         4.377
# 137          Egypt  2020  Middle East and North Africa         4.222
# 46       Argentina  2019                           NaN           NaN
#
#      Whisker-low  Dystopia + residual
# 136          NaN                  NaN
# 131        4.195                1.648
# 128        4.198                0.856
# 137        4.081                1.159
# 46           NaN                  NaN

# %%
df_origine_by_line.dtypes
# Out:
# country_official             object
# country                      object
# rank                        float64
# score                       float64
# PIB                         float64
# Soutien                     float64
# Esperance vie BS            float64
# Liberte des choix de vie    float64
# Generosite                  float64
# Corruption                  float64
# country_origin               object
# year                          int32
# Regional indicator           object
# Whisker-high                float64
# Whisker-low                 float64
# Dystopia + residual         float64
# dtype: object

# %%
df_origine_by_line.describe(include="all")
# Out:
#               country_official country        rank       score         PIB  \
# count                      597     597  299.000000  443.000000  443.000000
# unique                     157     165         NaN         NaN         NaN
# top     Arab Republic of Egypt   Egypt         NaN         NaN         NaN
# freq                         4       4         NaN         NaN         NaN
# mean                       NaN     NaN   76.093645    5.509287    6.747524
# std                        NaN     NaN   43.816938    1.088030    3.859714
# min                        NaN     NaN    1.000000    2.404000    0.000000
# 25%                        NaN     NaN   38.000000    4.770500    1.806000
# 50%                        NaN     NaN   76.000000    5.533000    8.485000
# 75%                        NaN     NaN  113.500000    6.260000    9.820000
# max                        NaN     NaN  156.000000    7.842000   11.647000
#
#            Soutien  Esperance vie BS  Liberte des choix de vie  Generosite  \
# count   443.000000        443.000000                443.000000  443.000000
# unique         NaN               NaN                       NaN         NaN
# top            NaN               NaN                       NaN         NaN
# freq           NaN               NaN                       NaN         NaN
# mean      0.841921         43.647752                  0.698424    0.037707
# std       0.192797         30.597451                  0.178520    0.153616
# min       0.000000          0.000000                  0.000000   -0.301000
# 25%       0.736000          0.730500                  0.588000   -0.083500
# 50%       0.855000         59.305000                  0.719000    0.050000
# 75%       0.935500         67.450500                  0.843000    0.134000
# max       1.320000         76.953000                  0.975000    0.561000
#
#         Corruption country_origin         year  Regional indicator  \
# count   443.000000            597   597.000000                 298
# unique         NaN            165          NaN                  10
# top            NaN          Egypt          NaN  Sub-Saharan Africa
# freq           NaN              4          NaN                  75
# mean      0.544819            NaN  2020.474037                 NaN
# std       0.315345            NaN     1.119419                 NaN
# min       0.000000            NaN  2019.000000                 NaN
# 25%       0.185000            NaN  2019.000000                 NaN
# 50%       0.684000            NaN  2020.000000                 NaN
# 75%       0.821000            NaN  2021.000000                 NaN
# max       0.939000            NaN  2022.000000                 NaN
#
#         Whisker-high  Whisker-low  Dystopia + residual
# count     443.000000   443.000000           443.000000
# unique           NaN          NaN                  NaN
# top              NaN          NaN                  NaN
# freq             NaN          NaN                  NaN
# mean        5.622822     5.395743             2.080054
# std         1.069728     1.107569             0.602309
# min         2.469000     2.339000             0.187000
# 25%         4.887000     4.645500             1.713500
# 50%         5.613000     5.420000             2.131000
# 75%         6.386000     6.145000             2.484500
# max         7.904000     7.780000             3.482000

# %%
df_origine_by_line.columns
# Out:
# Index(['country_official', 'country', 'rank', 'score', 'PIB', 'Soutien',
#        'Esperance vie BS', 'Liberte des choix de vie', 'Generosite',
#        'Corruption', 'country_origin', 'year', 'Regional indicator',
#        'Whisker-high', 'Whisker-low', 'Dystopia + residual'],
#       dtype='object')

# %%
df_origine_by_line = df_origine_by_line[['country_official', 'Regional indicator','country', 'country_origin','year', 'score', 'PIB', 'Soutien',
       'Esperance vie BS', 'Liberte des choix de vie', 'Generosite',
       'Corruption',  
       'Whisker-high', 'Whisker-low', 'Dystopia + residual','rank']]

# %%
figure, ax = color_graph_background(1,1)
sns.heatmap(df_origine_by_line.isnull(), yticklabels=False,cbar=False, cmap='viridis')
plt.xticks(rotation=45, ha="right", fontsize=10)
plt.title("NA dans la DF scores by line")
figure.set_size_inches(18, 5, forward=True)
plt.show()

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 2.3.x. Complément des données
# </div>

# %%
df_light_completed = df_origine_light_year_merged.copy()

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### 2.4. Fusion Détails des scores et évolution des scores
# </div>

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 2.2.1. Fusion dataset source et données temporelles
# </div>

# %% [markdown]
# <div style="display: flex; background-color: deeppink;" >
#
# ##### 2.2.1.x DF by line
# </div>

# %%
df_evolution_orgin.columns
# Out:
# Index(['country', 'score_2015', 'score_2016', 'score_2017', 'score_2018',
#        'score_2019', 'score_2020', 'country_official'],
#       dtype='object')

# %%
verbose = 1
df_light_completed_by_line = score_by_line_complete_with_historic_score(df_evolution_orgin, df_origine_by_line, verbose=verbose)
df_light_completed_by_line = fill_na_regional_indicator(df_light_completed_by_line, verbose=verbose)
print(df_light_completed_by_line.shape)
df_light_completed_by_line.head()
# Out:
# INPUT (597, 16)  dont score NA : 154
# OUTPUT (1378, 16)  dont score NA : 0
# INPUT Regional indicator NA :  1080 => OUTPUT :  46
# (1378, 16)
#          country_official            Regional indicator    country  \
# 0  Arab Republic of Egypt  Middle East and North Africa      Egypt
# 1  Arab Republic of Egypt  Middle East and North Africa      Egypt
# 2  Arab Republic of Egypt  Middle East and North Africa      Egypt
# 3      Argentine Republic   Latin America and Caribbean  Argentina
# 4      Argentine Republic   Latin America and Caribbean  Argentina
#
#   country_origin  year  score    PIB  Soutien  Esperance vie BS  \
# 0          Egypt  2021  4.283  9.367    0.750            61.998
# 1          Egypt  2022  4.288  1.388    0.732             0.548
# 2          Egypt  2020  4.151  9.317    0.735            61.780
# 3      Argentina  2021  5.929  9.962    0.898            69.000
# 4      Argentina  2020  5.975  9.811    0.901            68.804
#
#    Liberte des choix de vie  Generosite  Corruption  Whisker-high  \
# 0                     0.749      -0.182       0.795         4.371
# 1                     0.469       0.041       0.254         4.377
# 2                     0.708      -0.197       0.788         4.222
# 3                     0.828      -0.182       0.834         6.040
# 4                     0.831      -0.195       0.842         6.079
#
#    Whisker-low  Dystopia + residual   rank
# 0        4.195                1.648    NaN
# 1        4.198                0.856  129.0
# 2        4.081                1.159    NaN
# 3        5.819                2.461    NaN
# 4        5.870                2.073    NaN

# %%
df_light_completed_by_line = df_origine_by_line.copy()
df_evolution_orgin_by_line = df_evolution_orgin.copy()
for i in range (2015, 2021):
    # Création d'une DF temporaire pour inverser les valeurs
    df_temp = df_evolution_orgin_by_line[['country', 'country_official', 'score_'+str(i)]].copy()
    df_temp = df_temp[df_temp['score_'+str(i)].notna()]
    df_temp["year"] = i
    df_temp = df_temp.rename(columns={'score_'+str(i):"score"})

    # Concaténation des DF pour avoir une seule DF finale
    df_light_completed_by_line = pd.concat([df_light_completed_by_line, df_temp])

df_light_completed_by_line.columns
# Out:
# Index(['country_official', 'Regional indicator', 'country', 'country_origin',
#        'year', 'score', 'PIB', 'Soutien', 'Esperance vie BS',
#        'Liberte des choix de vie', 'Generosite', 'Corruption', 'Whisker-high',
#        'Whisker-low', 'Dystopia + residual', 'rank'],
#       dtype='object')

# %%
print(df_light_completed_by_line.shape)
df_light_completed_by_line.head()
# Out:
# (1532, 16)
#            country_official            Regional indicator    country  \
# 136  Arab Republic of Egypt                           NaN      Egypt
# 131  Arab Republic of Egypt  Middle East and North Africa      Egypt
# 128  Arab Republic of Egypt                           NaN      Egypt
# 137  Arab Republic of Egypt  Middle East and North Africa      Egypt
# 46       Argentine Republic                           NaN  Argentina
#
#     country_origin  year  score    PIB  Soutien  Esperance vie BS  \
# 136          Egypt  2019    NaN    NaN      NaN               NaN
# 131          Egypt  2021  4.283  9.367    0.750            61.998
# 128          Egypt  2022  4.288  1.388    0.732             0.548
# 137          Egypt  2020  4.151  9.317    0.735            61.780
# 46       Argentina  2019    NaN    NaN      NaN               NaN
#
#      Liberte des choix de vie  Generosite  Corruption  Whisker-high  \
# 136                       NaN         NaN         NaN           NaN
# 131                     0.749      -0.182       0.795         4.371
# 128                     0.469       0.041       0.254         4.377
# 137                     0.708      -0.197       0.788         4.222
# 46                        NaN         NaN         NaN           NaN
#
#      Whisker-low  Dystopia + residual   rank
# 136          NaN                  NaN  137.0
# 131        4.195                1.648    NaN
# 128        4.198                0.856  129.0
# 137        4.081                1.159    NaN
# 46           NaN                  NaN   47.0

# %%
df_light_completed_by_line.columns
# Out:
# Index(['country_official', 'Regional indicator', 'country', 'country_origin',
#        'year', 'score', 'PIB', 'Soutien', 'Esperance vie BS',
#        'Liberte des choix de vie', 'Generosite', 'Corruption', 'Whisker-high',
#        'Whisker-low', 'Dystopia + residual', 'rank'],
#       dtype='object')

# %% [markdown]
# On complète la région

# %%
regions_group = df_light_completed_by_line[df_light_completed_by_line['Regional indicator'].notna()].groupby(['country_official', 'Regional indicator']).agg({'Regional indicator':['count']})
regions_group = regions_group.reset_index()
regions_group.columns = regions_group.columns.droplevel()
regions_group.columns = ['country_official', 'Regional indicator2',"count Regional indicator"]
regions_group.columns
# Out:
# Index(['country_official', 'Regional indicator2', 'count Regional indicator'], dtype='object')

# %%
regions_group = regions_group.sort_values(by=['count Regional indicator'], ascending=False)
regions_group.tail()
# Out:
#                      country_official          Regional indicator2  \
# 150                           Vietnam               Southeast Asia
# 8    Democratic Republic Of The Congo           Sub-Saharan Africa
# 118   Republic of Trinidad and Tobago  Latin America and Caribbean
# 6            Central African Republic           Sub-Saharan Africa
# 116           Republic of South Sudan           Sub-Saharan Africa
#
#      count Regional indicator
# 150                         2
# 8                           1
# 118                         1
# 6                           1
# 116                         1

# %%
print(regions_group.shape)
regions_group = regions_group.drop_duplicates(subset=["country_official"], keep="first")
regions_group = regions_group.drop("count Regional indicator", axis=1)
print(regions_group.shape)
# Out:
# (151, 3)
# (151, 2)

# %%
df_light_completed_by_line = df_light_completed_by_line.merge(regions_group, on="country_official", how="left", indicator=False)
print(df_light_completed_by_line["Regional indicator"].isna().sum())
df_light_completed_by_line["Regional indicator"] = df_light_completed_by_line["Regional indicator"].fillna(df_light_completed_by_line["Regional indicator2"])
print(df_light_completed_by_line["Regional indicator"].isna().sum())
df_light_completed_by_line = df_light_completed_by_line.drop(["Regional indicator2"], axis=1)
df_light_completed_by_line.head()
# Out:
# 1234
# 51
#          country_official            Regional indicator    country  \
# 0  Arab Republic of Egypt  Middle East and North Africa      Egypt
# 1  Arab Republic of Egypt  Middle East and North Africa      Egypt
# 2  Arab Republic of Egypt  Middle East and North Africa      Egypt
# 3  Arab Republic of Egypt  Middle East and North Africa      Egypt
# 4      Argentine Republic   Latin America and Caribbean  Argentina
#
#   country_origin  year  score    PIB  Soutien  Esperance vie BS  \
# 0          Egypt  2019    NaN    NaN      NaN               NaN
# 1          Egypt  2021  4.283  9.367    0.750            61.998
# 2          Egypt  2022  4.288  1.388    0.732             0.548
# 3          Egypt  2020  4.151  9.317    0.735            61.780
# 4      Argentina  2019    NaN    NaN      NaN               NaN
#
#    Liberte des choix de vie  Generosite  Corruption  Whisker-high  \
# 0                       NaN         NaN         NaN           NaN
# 1                     0.749      -0.182       0.795         4.371
# 2                     0.469       0.041       0.254         4.377
# 3                     0.708      -0.197       0.788         4.222
# 4                       NaN         NaN         NaN           NaN
#
#    Whisker-low  Dystopia + residual   rank
# 0          NaN                  NaN  137.0
# 1        4.195                1.648    NaN
# 2        4.198                0.856  129.0
# 3        4.081                1.159    NaN
# 4          NaN                  NaN   47.0

# %%
print(df_light_completed_by_line.shape)
df_light_completed_by_line = df_light_completed_by_line[df_light_completed_by_line["score"].notna()]
print(df_light_completed_by_line.shape)

# %%
figure, ax = color_graph_background(1,1)
sns.heatmap(df_light_completed_by_line.isnull(), yticklabels=False,cbar=False, cmap='viridis')
plt.xticks(rotation=45, ha="right", fontsize=10)
plt.title("NA dans la DF scores by line")
figure.set_size_inches(18, 5, forward=True)
plt.show()

# %%
df_light_completed_by_line.shape

# %% [markdown]
# <div style="display: flex; background-color: deeppink;" >
#
# ##### 2.2.1.x DF by columns
# </div>

# %%
df_light_merged = df_light_completed.merge(df_evolution_orgin, on=country_official_col_name, how="outer", indicator=True)
df_light_merged = df_light_merged.rename(columns={"country":"country_FR"})
print(df_light_completed.shape, df_evolution_orgin.shape, df_light_merged.shape)
print(list(df_light_merged.columns))
df_light_merged = df_light_merged.sort_values(by=country_official_col_name)
df_light_merged = df_light_merged.reset_index()
df_light_merged = df_light_merged.drop("index", axis=1)
df_light_merged.head()
# Out:
# (157, 42) (165, 8) (166, 50)
# ['country_official', 'country_origin', 'Regional indicator', '2019', '2020', '2021', '2022', '2019-rank', '2019-Soutien', '2022-rank', '2019-PIB', '2020-PIB', '2022-PIB', '2021-PIB', '2019-Esperance vie BS', '2019-Liberte des choix de vie', '2019-Generosite', '2019-Corruption', '2020-Whisker-high', '2020-Whisker-low', '2020-Soutien', '2020-Esperance vie BS', '2020-Liberte des choix de vie', '2020-Generosite', '2020-Corruption', '2020-Dystopia + residual', '2021-Whisker-high', '2021-Whisker-low', '2021-Soutien', '2021-Esperance vie BS', '2021-Liberte des choix de vie', '2021-Generosite', '2021-Corruption', '2021-Dystopia + residual', '2022-Whisker-high', '2022-Whisker-low', '2022-Dystopia + residual', '2022-Soutien', '2022-Esperance vie BS', '2022-Liberte des choix de vie', '2022-Generosite', '2022-Corruption', 'country_FR', 'score_2015', 'score_2016', 'score_2017', 'score_2018', 'score_2019', 'score_2020', '_merge']
#          country_official country_origin            Regional indicator   2019  \
# 0  Arab Republic of Egypt          Egypt  Middle East and North Africa  4.166
# 1      Argentine Republic      Argentina   Latin America and Caribbean  6.086
# 2               Australia      Australia         North America and ANZ  7.228
# 3                  Belize            NaN                           NaN    NaN
# 4                 Bolivia        Bolivia   Latin America and Caribbean  5.779
#
#     2020   2021   2022  2019-rank  2019-Soutien  2022-rank  ...  \
# 0  4.151  4.283  4.288      137.0         1.039      129.0  ...
# 1  5.975  5.929  5.967       47.0         1.432       57.0  ...
# 2  7.223  7.183  7.162       11.0         1.548       12.0  ...
# 3    NaN    NaN    NaN        NaN           NaN        NaN  ...
# 4  5.747  5.716  5.600       61.0         1.209       71.0  ...
#
#    2022-Generosite  2022-Corruption  country_FR  score_2015  score_2016  \
# 0            0.041            0.254      Égypte       4.194       4.362
# 1            0.081            0.085   Argentine       6.574       6.650
# 2            0.258            0.341   Australie       7.284       7.313
# 3              NaN              NaN      Belize         NaN       5.956
# 4            0.112            0.064     Bolivie       5.890       5.822
#
#    score_2017  score_2018  score_2019  score_2020      _merge
# 0       4.735       4.419       4.166       4.151        both
# 1       6.599       6.388       6.086       5.975        both
# 2       7.284       7.272       7.228       7.223        both
# 3       5.956       5.956         NaN         NaN  right_only
# 4       5.823       5.752       5.779       5.747        both
#
# [5 rows x 50 columns]

# %%
df_light_merged["country_official"].value_counts()
# Out:
# Republic of Cyprus                         2
# United States of America                   2
# Federal Republic of Somalia                2
# Arab Republic of Egypt                     1
# Republic of Panama                         1
#                                           ..
# Mongolia                                   1
# Montenegro                                 1
# New Zealand                                1
# People's Democratic Republic of Algeria    1
# Vietnam                                    1
# Name: country_official, Length: 163, dtype: int64

# %%
# Il faut supprimer les doublons
df_light_merged["NB_NA"] = df_light_merged.isna().sum(axis=1)
df_light_merged = df_light_merged.sort_values(by="NB_NA", ascending=True)
df_light_merged[["country_official","NB_NA"]].head()
# Out:
#            country_official  NB_NA
# 0    Arab Republic of Egypt      0
# 98   Republic of Kazakhstan      0
# 99        Republic of Kenya      0
# 100      Republic of Latvia      0
# 101     Republic of Liberia      0

# %%
df_light_merged = df_light_merged.drop_duplicates(subset=[country_official_col_name], keep="first")
df_light_merged = df_light_merged.drop(columns=["NB_NA"])
df_light_merged["country_official"].value_counts()
# Out:
# Arab Republic of Egypt             1
# People's Republic of Bangladesh    1
# Federal Republic of Nigeria        1
# Federative Republic of Brazil      1
# Dominican Republic                 1
#                                   ..
# Republic of the Philippines        1
# Republic of Serbia                 1
# Republic of Sierra Leone           1
# Republic of Singapore              1
# Republic of Djibouti               1
# Name: country_official, Length: 163, dtype: int64

# %%
df_light_merged.describe(include="all")
# Out:
#               country_official country_origin  Regional indicator        2019  \
# count                      163            157                 151  154.000000
# unique                     163            157                  10         NaN
# top     Arab Republic of Egypt          Egypt  Sub-Saharan Africa         NaN
# freq                         1              1                  39         NaN
# mean                       NaN            NaN                 NaN    5.410708
# std                        NaN            NaN                 NaN    1.114996
# min                        NaN            NaN                 NaN    2.853000
# 25%                        NaN            NaN                 NaN    4.550750
# 50%                        NaN            NaN                 NaN    5.379500
# 75%                        NaN            NaN                 NaN    6.189500
# max                        NaN            NaN                 NaN    7.769000
#
#               2020        2021        2022   2019-rank  2019-Soutien  \
# count   151.000000  147.000000  145.000000  154.000000    154.000000
# unique         NaN         NaN         NaN         NaN           NaN
# top            NaN         NaN         NaN         NaN           NaN
# freq           NaN         NaN         NaN         NaN           NaN
# mean      5.460391    5.520367    5.548972   78.324675      1.209110
# std       1.109022    1.070520    1.089181   45.178496      0.301099
# min       2.567000    2.523000    2.404000    1.000000      0.000000
# 25%       4.700500    4.843000    4.888000   39.250000      1.055250
# 50%       5.510000    5.477000    5.559000   78.500000      1.275500
# 75%       6.227500    6.239000    6.309000  116.750000      1.453500
# max       7.809000    7.842000    7.821000  156.000000      1.624000
#
#          2022-rank  ...  2022-Generosite  2022-Corruption  country_FR  \
# count   145.000000  ...       145.000000       145.000000         162
# unique         NaN  ...              NaN              NaN         162
# top            NaN  ...              NaN              NaN      Égypte
# freq           NaN  ...              NaN              NaN           1
# mean     73.724138  ...         0.147545         0.155421         NaN
# std      42.350141  ...         0.083061         0.127721         NaN
# min       1.000000  ...         0.000000         0.000000         NaN
# 25%      37.000000  ...         0.089000         0.069000         NaN
# 50%      74.000000  ...         0.134000         0.123000         NaN
# 75%     110.000000  ...         0.198000         0.200000         NaN
# max     146.000000  ...         0.468000         0.587000         NaN
#
#         score_2015  score_2016  score_2017  score_2018  score_2019  \
# count   156.000000  154.000000  154.000000  155.000000  155.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean      5.375673    5.371013    5.364747    5.372955    5.405026
# std       1.151710    1.144216    1.145560    1.122521    1.116410
# min       2.839000    2.905000    2.693000    2.905000    2.853000
# 25%       4.517750    4.397250    4.501250    4.451500    4.541000
# 50%       5.232500    5.308500    5.286000    5.358000    5.373000
# 75%       6.275500    6.261500    6.152250    6.170000    6.187000
# max       7.587000    7.526000    7.537000    7.632000    7.769000
#
#         score_2020  _merge
# count   152.000000     163
# unique         NaN       3
# top            NaN    both
# freq           NaN     156
# mean      5.472842     NaN
# std       1.115953     NaN
# min       2.567000     NaN
# 25%       4.712250     NaN
# 50%       5.512500     NaN
# 75%       6.235500     NaN
# max       7.809000     NaN
#
# [11 rows x 50 columns]

# %%
df_light_merged[df_light_merged["country_origin"].isna()]
# Out:
#           country_official country_origin Regional indicator  2019  2020  \
# 139  Republic of the Sudan            NaN                NaN   NaN   NaN
# 65      Republic of Angola            NaN                NaN   NaN   NaN
# 3                   Belize            NaN                NaN   NaN   NaN
# 125   Republic of Suriname            NaN                NaN   NaN   NaN
# 149      Sultanate of Oman            NaN                NaN   NaN   NaN
# 84    Republic of Djibouti            NaN                NaN   NaN   NaN
#
#      2021  2022  2019-rank  2019-Soutien  2022-rank  ...  2022-Generosite  \
# 139   NaN   NaN        NaN           NaN        NaN  ...              NaN
# 65    NaN   NaN        NaN           NaN        NaN  ...              NaN
# 3     NaN   NaN        NaN           NaN        NaN  ...              NaN
# 125   NaN   NaN        NaN           NaN        NaN  ...              NaN
# 149   NaN   NaN        NaN           NaN        NaN  ...              NaN
# 84    NaN   NaN        NaN           NaN        NaN  ...              NaN
#
#      2022-Corruption  country_FR  score_2015  score_2016  score_2017  \
# 139              NaN      Soudan       4.550       4.139       4.139
# 65               NaN      Angola       4.033       3.866       3.795
# 3                NaN      Belize         NaN       5.956       5.956
# 125              NaN    Suriname       6.269       6.269         NaN
# 149              NaN        Oman       6.853         NaN         NaN
# 84               NaN    Djibouti       4.369         NaN         NaN
#
#      score_2018  score_2019  score_2020      _merge
# 139       4.139         NaN         NaN  right_only
# 65        3.795         NaN         NaN  right_only
# 3         5.956         NaN         NaN  right_only
# 125         NaN         NaN         NaN  right_only
# 149         NaN         NaN         NaN  right_only
# 84          NaN         NaN         NaN  right_only
#
# [6 rows x 50 columns]

# %%
# Complément des données manquantes
print(f"2019 : {df_light_merged['2019'].isna().sum()} NA", end="")
df_light_merged["2019"] = df_light_merged["2019"].fillna(df_light_merged["score_2019"])
print(f" => AFTER 2019 : {df_light_merged['2019'].isna().sum()} NA")

print(f"2020 : {df_light_merged['2020'].isna().sum()} NA", end="")
df_light_merged["2020"] = df_light_merged["2020"].fillna(df_light_merged["score_2020"])
print(f" => AFTER 2020 : {df_light_merged['2020'].isna().sum()} NA")

print(f"country_origin : {df_light_merged['country_origin'].isna().sum()} NA", end="")
df_light_merged["country_origin"] = df_light_merged["country_origin"].fillna(df_light_merged["country_FR"])
print(f" => AFTER country_origin : {df_light_merged['country_origin'].isna().sum()} NA")
# Out:
# 2019 : 9 NA => AFTER 2019 : 8 NA
# 2020 : 12 NA => AFTER 2020 : 10 NA
# country_origin : 6 NA => AFTER country_origin : 0 NA

# %%
df_light_merged["_merge"].value_counts()
# Out:
# both          156
# right_only      6
# left_only       1
# Name: _merge, dtype: int64

# %%
df_light_merged[df_light_merged["_merge"]=="right_only"]
# Out:
#           country_official country_origin Regional indicator  2019  2020  \
# 139  Republic of the Sudan         Soudan                NaN   NaN   NaN
# 65      Republic of Angola         Angola                NaN   NaN   NaN
# 3                   Belize         Belize                NaN   NaN   NaN
# 125   Republic of Suriname       Suriname                NaN   NaN   NaN
# 149      Sultanate of Oman           Oman                NaN   NaN   NaN
# 84    Republic of Djibouti       Djibouti                NaN   NaN   NaN
#
#      2021  2022  2019-rank  2019-Soutien  2022-rank  ...  2022-Generosite  \
# 139   NaN   NaN        NaN           NaN        NaN  ...              NaN
# 65    NaN   NaN        NaN           NaN        NaN  ...              NaN
# 3     NaN   NaN        NaN           NaN        NaN  ...              NaN
# 125   NaN   NaN        NaN           NaN        NaN  ...              NaN
# 149   NaN   NaN        NaN           NaN        NaN  ...              NaN
# 84    NaN   NaN        NaN           NaN        NaN  ...              NaN
#
#      2022-Corruption  country_FR  score_2015  score_2016  score_2017  \
# 139              NaN      Soudan       4.550       4.139       4.139
# 65               NaN      Angola       4.033       3.866       3.795
# 3                NaN      Belize         NaN       5.956       5.956
# 125              NaN    Suriname       6.269       6.269         NaN
# 149              NaN        Oman       6.853         NaN         NaN
# 84               NaN    Djibouti       4.369         NaN         NaN
#
#      score_2018  score_2019  score_2020      _merge
# 139       4.139         NaN         NaN  right_only
# 65        3.795         NaN         NaN  right_only
# 3         5.956         NaN         NaN  right_only
# 125         NaN         NaN         NaN  right_only
# 149         NaN         NaN         NaN  right_only
# 84          NaN         NaN         NaN  right_only
#
# [6 rows x 50 columns]

# %%
df_light_merged_clean = df_light_merged[~((df_light_merged["_merge"]=="right_only") & (df_light_merged["2019"].isna()) & (df_light_merged["2020"].isna()))]
print(f"{df_light_merged.shape}, {df_light_merged_clean.shape}")
df_light_merged_clean
# Out:
# (163, 50), (157, 50)
#                 country_official        country_origin  \
# 0         Arab Republic of Egypt                 Egypt
# 98        Republic of Kazakhstan            Kazakhstan
# 99             Republic of Kenya                 Kenya
# 100           Republic of Latvia                Latvia
# 101          Republic of Liberia               Liberia
# ..                           ...                   ...
# 13          Eswatini, Kingdom of  Eswatini, Kingdom of
# 39             Kingdom of Bhutan                Bhutan
# 148               State of Qatar                 Qatar
# 151                        Syria                 Syria
# 18   Federal Republic of Somalia               Somalia
#
#                      Regional indicator   2019   2020   2021   2022  \
# 0          Middle East and North Africa  4.166  4.151  4.283  4.288
# 98   Commonwealth of Independent States  5.809  6.058  6.152  6.234
# 99                   Sub-Saharan Africa  4.509  4.583  4.607  4.543
# 100          Central and Eastern Europe  5.940  5.950  6.032  6.180
# 101                  Sub-Saharan Africa  3.975  4.558  4.625  5.122
# ..                                  ...    ...    ...    ...    ...
# 13                                  NaN  4.212  4.308    NaN  4.396
# 39                                  NaN  5.082    NaN    NaN    NaN
# 148                                 NaN  6.374    NaN    NaN    NaN
# 151                                 NaN  3.462    NaN    NaN    NaN
# 18                                  NaN  4.668    NaN    NaN    NaN
#
#      2019-rank  2019-Soutien  2022-rank  ...  2022-Generosite  \
# 0        137.0         1.039      129.0  ...            0.041
# 98        60.0         1.508       40.0  ...            0.134
# 99       121.0         0.983      119.0  ...            0.322
# 100       53.0         1.465       42.0  ...            0.075
# 101      141.0         0.922       97.0  ...            0.178
# ..         ...           ...        ...  ...              ...
# 13         NaN           NaN      125.0  ...            0.038
# 39        95.0         1.321        NaN  ...              NaN
# 148       29.0         1.313        NaN  ...              NaN
# 151      149.0         0.378        NaN  ...              NaN
# 18       112.0         0.698        NaN  ...              NaN
#
#      2022-Corruption  country_FR  score_2015  score_2016  score_2017  \
# 0              0.254      Égypte       4.194       4.362       4.735
# 98             0.157  Kazakhstan       5.855       5.919       5.819
# 99             0.082       Kenya       4.419       4.356       4.553
# 100            0.090    Lettonie       5.098       5.560       5.850
# 101            0.080     Liberia       4.571       3.622       3.533
# ..               ...         ...         ...         ...         ...
# 13             0.154    Eswatini       4.867         NaN         NaN
# 39               NaN     Bhoutan       5.253       5.196       5.011
# 148              NaN       Qatar       6.611       6.375       6.375
# 151              NaN       Syrie       3.006       3.069       3.462
# 18               NaN     Somalie         NaN       5.440       5.151
#
#      score_2018  score_2019  score_2020  _merge
# 0         4.419       4.166       4.151    both
# 98        5.790       5.809       6.058    both
# 99        4.410       4.509       4.583    both
# 100       5.933       5.940       5.950    both
# 101       3.495       3.975       4.558    both
# ..          ...         ...         ...     ...
# 13          NaN       4.212       4.308    both
# 39        5.082       5.082         NaN    both
# 148       6.374       6.374         NaN    both
# 151       3.462       3.462         NaN    both
# 18        4.982       4.668         NaN    both
#
# [157 rows x 50 columns]

# %%
df_light_merged_clean["_merge"].value_counts()
# Out:
# both          156
# left_only       1
# right_only      0
# Name: _merge, dtype: int64

# %%
display(HTML(df_light_merged_clean[df_light_merged_clean["_merge"] != "both"].to_html()))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country_official</th>
#       <th>country_origin</th>
#       <th>Regional indicator</th>
#       <th>2019</th>
#       <th>2020</th>
#       <th>2021</th>
#       <th>2022</th>
#       <th>2019-rank</th>
#       <th>2019-Soutien</th>
#       <th>2022-rank</th>
#       <th>2019-PIB</th>
#       <th>2020-PIB</th>
#       <th>2022-PIB</th>
#       <th>2021-PIB</th>
#       <th>2019-Esperance vie BS</th>
#       <th>2019-Liberte des choix de vie</th>
#       <th>2019-Generosite</th>
#       <th>2019-Corruption</th>
#       <th>2020-Whisker-high</th>
#       <th>2020-Whisker-low</th>
#       <th>2020-Soutien</th>
#       <th>2020-Esperance vie BS</th>
#       <th>2020-Liberte des choix de vie</th>
#       <th>2020-Generosite</th>
#       <th>2020-Corruption</th>
#       <th>2020-Dystopia + residual</th>
#       <th>2021-Whisker-high</th>
#       <th>2021-Whisker-low</th>
#       <th>2021-Soutien</th>
#       <th>2021-Esperance vie BS</th>
#       <th>2021-Liberte des choix de vie</th>
#       <th>2021-Generosite</th>
#       <th>2021-Corruption</th>
#       <th>2021-Dystopia + residual</th>
#       <th>2022-Whisker-high</th>
#       <th>2022-Whisker-low</th>
#       <th>2022-Dystopia + residual</th>
#       <th>2022-Soutien</th>
#       <th>2022-Esperance vie BS</th>
#       <th>2022-Liberte des choix de vie</th>
#       <th>2022-Generosite</th>
#       <th>2022-Corruption</th>
#       <th>country_FR</th>
#       <th>score_2015</th>
#       <th>score_2016</th>
#       <th>score_2017</th>
#       <th>score_2018</th>
#       <th>score_2019</th>
#       <th>score_2020</th>
#       <th>_merge</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>153</th>
#       <td>Taiwan Province of China</td>
#       <td>Taiwan Province of China</td>
#       <td>East Asia</td>
#       <td>NaN</td>
#       <td>6.455</td>
#       <td>6.584</td>
#       <td>6.512</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>26.0</td>
#       <td>NaN</td>
#       <td>10.776</td>
#       <td>1.897</td>
#       <td>10.871</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>6.532</td>
#       <td>6.379</td>
#       <td>0.894</td>
#       <td>69.6</td>
#       <td>0.772</td>
#       <td>-0.073</td>
#       <td>0.732</td>
#       <td>2.16</td>
#       <td>6.659</td>
#       <td>6.51</td>
#       <td>0.898</td>
#       <td>69.6</td>
#       <td>0.784</td>
#       <td>-0.07</td>
#       <td>0.721</td>
#       <td>2.687</td>
#       <td>6.596</td>
#       <td>6.429</td>
#       <td>2.002</td>
#       <td>1.095</td>
#       <td>0.733</td>
#       <td>0.542</td>
#       <td>0.075</td>
#       <td>0.168</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>NaN</td>
#       <td>left_only</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Réorganisation des colonnes
cols_names = list(df_light_merged.columns)
cols_names.remove('country_FR')
init_pos = 3
for i in range(2015, 2021, 1):
    c_n = 'score_'+str(i)
    if i > 2018:
        c_n2 = str(i)
        cols_names.remove(c_n2)
        cols_names.insert(init_pos, c_n2)
        init_pos += 1
    cols_names.remove(c_n)
    cols_names.insert(init_pos, c_n)
    init_pos += 1
    
# score_2015	score_2016	score_2017	score_2018	score_2019	score_2020
cols_names.insert(3, 'country_FR')
df_light_merged = df_light_merged[cols_names]
df_light_merged[['country_official', 'country_origin', 'Regional indicator',
       'country_FR', 'score_2015', 'score_2016', 'score_2017', 'score_2018',
       '2019', 'score_2019', '2020', 'score_2020', '2021', '2022','_merge']].head()
# Out:
#            country_official country_origin  \
# 0    Arab Republic of Egypt          Egypt
# 98   Republic of Kazakhstan     Kazakhstan
# 99        Republic of Kenya          Kenya
# 100      Republic of Latvia         Latvia
# 101     Republic of Liberia        Liberia
#
#                      Regional indicator  country_FR  score_2015  score_2016  \
# 0          Middle East and North Africa      Égypte       4.194       4.362
# 98   Commonwealth of Independent States  Kazakhstan       5.855       5.919
# 99                   Sub-Saharan Africa       Kenya       4.419       4.356
# 100          Central and Eastern Europe    Lettonie       5.098       5.560
# 101                  Sub-Saharan Africa     Liberia       4.571       3.622
#
#      score_2017  score_2018   2019  score_2019   2020  score_2020   2021  \
# 0         4.735       4.419  4.166       4.166  4.151       4.151  4.283
# 98        5.819       5.790  5.809       5.809  6.058       6.058  6.152
# 99        4.553       4.410  4.509       4.509  4.583       4.583  4.607
# 100       5.850       5.933  5.940       5.940  5.950       5.950  6.032
# 101       3.533       3.495  3.975       3.975  4.558       4.558  4.625
#
#       2022 _merge
# 0    4.288   both
# 98   6.234   both
# 99   4.543   both
# 100  6.180   both
# 101  5.122   both

# %%
figure, ax = color_graph_background(1,1)
sns.heatmap(df_light_merged.isnull(), yticklabels=False,cbar=False, cmap='viridis')
plt.xticks(rotation=45, ha="right", fontsize=10)
plt.title("NA dans la DF")
figure.set_size_inches(18, 5, forward=True)
plt.show()

# %%
df_light_merged.hist(figsize=(18,18),bins=50)
plt.show()

# %%
df_light_merged.loc[(df_light_merged["country_origin"].isna()) & (df_light_merged["score_2019"].notna()) ,['country_official', 'country_origin', 'Regional indicator',
       'country_FR', 'score_2015', 'score_2016', 'score_2017', 'score_2018',
       '2019', 'score_2019', '2020', 'score_2020', '2021', '2022','_merge']]
# Out:
# Empty DataFrame
# Columns: [country_official, country_origin, Regional indicator, country_FR, score_2015, score_2016, score_2017, score_2018, 2019, score_2019, 2020, score_2020, 2021, 2022, _merge]
# Index: []

# %%
df_light_merged.loc[(df_light_merged["country_official"].str.contains("Sudan")) | (df_light_merged["country_origin"].str.contains("Sudan")) ,['country_official', 'country_origin', 'Regional indicator',
       'country_FR', 'score_2015', 'score_2016', 'score_2017', 'score_2018',
       '2019', 'score_2019', '2020', 'score_2020', '2021', '2022','_merge']]
# Out:
#             country_official country_origin  Regional indicator  \
# 146  Republic of South Sudan    South Sudan  Sub-Saharan Africa
# 161    Republic of the Sudan            NaN                 NaN
#
#         country_FR  score_2015  score_2016  score_2017  score_2018   2019  \
# 146  Soudan du Sud         NaN       3.832       3.591       3.254  2.853
# 161         Soudan        4.55       4.139       4.139       4.139    NaN
#
#      score_2019   2020  score_2020  2021  2022      _merge
# 146       2.853  2.817       2.817   NaN   NaN        both
# 161         NaN    NaN         NaN   NaN   NaN  right_only

# %%
print(df_light_merged["country_official"].duplicated().count())
df_light_merged[df_light_merged["country_official"].duplicated()]
# Out:
# 165
# Empty DataFrame
# Columns: [country_official, country_origin, Regional indicator, 2019, 2020, 2021, 2022, 2019-rank, 2019-Soutien, 2022-rank, 2019-PIB, 2020-PIB, 2022-PIB, 2021-PIB, 2019-Esperance vie BS, 2019-Liberte des choix de vie, 2019-Generosite, 2019-Corruption, 2020-Whisker-high, 2020-Whisker-low, 2020-Soutien, 2020-Esperance vie BS, 2020-Liberte des choix de vie, 2020-Generosite, 2020-Corruption, 2020-Dystopia + residual, 2021-Whisker-high, 2021-Whisker-low, 2021-Soutien, 2021-Esperance vie BS, 2021-Liberte des choix de vie, 2021-Generosite, 2021-Corruption, 2021-Dystopia + residual, 2022-Whisker-high, 2022-Whisker-low, 2022-Dystopia + residual, 2022-Soutien, 2022-Esperance vie BS, 2022-Liberte des choix de vie, 2022-Generosite, 2022-Corruption, country_FR, score_2015, score_2016, score_2017, score_2018, score_2019, score_2020, _merge, NB_NA]
# Index: []
#
# [0 rows x 51 columns]

# %%
df_light_merged.iloc[48:53]
# Out:
#      country_official country_origin  Regional indicator country_FR  \
# 48  Kingdom of Sweden      Swaziland      Western Europe      Suède
# 49  Kingdom of Sweden         Sweden  Sub-Saharan Africa      Suède
# 50  Kingdom of Sweden      Swaziland      Western Europe      Suède
# 51  Kingdom of Sweden         Sweden      Western Europe      Suède
# 52  Kingdom of Sweden      Swaziland  Sub-Saharan Africa      Suède
#
#     score_2015  score_2016  score_2017  score_2018   2019  score_2019  ...  \
# 48       7.364       7.291       7.284       7.314  4.212       7.343  ...
# 49       7.364       7.291       7.284       7.314  7.343       7.343  ...
# 50       7.364       7.291       7.284       7.314  4.212       7.343  ...
# 51       7.364       7.291       7.284       7.314  7.343       7.343  ...
# 52       7.364       7.291       7.284       7.314  4.212       7.343  ...
#
#     2021-Dystopia + residual  2022-Whisker-high  2022-Whisker-low  \
# 48                     2.683              7.454             7.315
# 49                     2.155              7.454             7.315
# 50                     2.155              7.454             7.315
# 51                     2.155              7.454             7.315
# 52                     2.155              7.454             7.315
#
#     2022-Dystopia + residual  2022-Soutien  2022-Esperance vie BS  \
# 48                     2.003         1.204                  0.803
# 49                     2.003         1.204                  0.803
# 50                     2.003         1.204                  0.803
# 51                     2.003         1.204                  0.803
# 52                     2.003         1.204                  0.803
#
#     2022-Liberte des choix de vie  2022-Generosite  2022-Corruption  _merge
# 48                          0.724            0.218            0.512    both
# 49                          0.724            0.218            0.512    both
# 50                          0.724            0.218            0.512    both
# 51                          0.724            0.218            0.512    both
# 52                          0.724            0.218            0.512    both
#
# [5 rows x 50 columns]

# %%
col1 = '2019'
col2 = 'score_'+col1

diff = df_light_merged[(df_light_merged[col1] != df_light_merged[col2]) & (df_light_merged[col2].notna()) & (df_light_merged[col1].notna())]
print(diff.shape)
diff[['country_official', 'country_origin', 'Regional indicator',
       'country_FR', col1, col2,'_merge']]
# Out:
# (5, 50)
#       country_official country_origin            Regional indicator  \
# 48   Kingdom of Sweden      Swaziland                Western Europe
# 50   Kingdom of Sweden      Swaziland                Western Europe
# 52   Kingdom of Sweden      Swaziland            Sub-Saharan Africa
# 53   Kingdom of Sweden      Swaziland            Sub-Saharan Africa
# 168    State of Kuwait         Kuwait  Middle East and North Africa
#
#     country_FR   2019  score_2019 _merge
# 48       Suède  4.212       7.343   both
# 50       Suède  4.212       7.343   both
# 52       Suède  4.212       7.343   both
# 53       Suède  4.212       7.343   both
# 168     Koweït  6.021       6.011   both

# %%
df_light_merged[df_light_merged["country_official"].str.contains("Congo")]
# Out:
#                      country_official       country_origin  \
# 9    Democratic Republic Of The Congo     Congo (Kinshasa)
# 157             Republic of the Congo  Congo (Brazzaville)
#
#      Regional indicator   country_FR  score_2015  score_2016  score_2017  \
# 9    Sub-Saharan Africa  Congo (RDC)       4.517       4.236       4.280
# 157  Sub-Saharan Africa        Congo       3.989       4.272       4.291
#
#      score_2018   2019  score_2019  ...  2021-Dystopia + residual  \
# 9         4.245  4.418       4.418  ...                       NaN
# 157       4.559  4.812       4.812  ...                     3.476
#
#      2022-Whisker-high  2022-Whisker-low  2022-Dystopia + residual  \
# 9                  NaN               NaN                       NaN
# 157              5.235             4.915                     2.658
#
#      2022-Soutien  2022-Esperance vie BS  2022-Liberte des choix de vie  \
# 9             NaN                    NaN                            NaN
# 157         0.405                  0.355                          0.431
#
#      2022-Generosite  2022-Corruption  _merge
# 9                NaN              NaN    both
# 157             0.13            0.146    both
#
# [2 rows x 50 columns]

# %%
col1 = '2020'
col2 = 'score_'+col1

diff = df_light_merged[(df_light_merged[col1] != df_light_merged[col2]) & (df_light_merged[col2].notna()) & (df_light_merged[col1].notna())]
print(diff.shape)
diff[['country_official', 'country_origin', 'Regional indicator',
       'country_FR', col1, col2,'_merge']]
# Out:
# (4, 50)
#      country_official country_origin  Regional indicator country_FR   2020  \
# 49  Kingdom of Sweden         Sweden  Sub-Saharan Africa      Suède  4.308
# 52  Kingdom of Sweden      Swaziland  Sub-Saharan Africa      Suède  4.308
# 53  Kingdom of Sweden      Swaziland  Sub-Saharan Africa      Suède  4.308
# 54  Kingdom of Sweden         Sweden  Sub-Saharan Africa      Suède  4.308
#
#     score_2020 _merge
# 49       7.353   both
# 52       7.353   both
# 53       7.353   both
# 54       7.353   both

# %%
df_light_merged.columns
# Out:
# Index(['country_official', 'country_origin', 'Regional indicator',
#        'country_FR', 'score_2015', 'score_2016', 'score_2017', 'score_2018',
#        '2019', 'score_2019', '2020', 'score_2020', '2021', '2022', '2019-rank',
#        '2019-Soutien', '2022-rank', '2019-PIB', '2020-PIB', '2022-PIB',
#        '2021-PIB', '2019-Esperance vie BS', '2019-Liberte des choix de vie',
#        '2019-Generosite', '2019-Corruption', '2020-Whisker-high',
#        '2020-Whisker-low', '2020-Soutien', '2020-Esperance vie BS',
#        '2020-Liberte des choix de vie', '2020-Generosite', '2020-Corruption',
#        '2020-Dystopia + residual', '2021-Whisker-high', '2021-Whisker-low',
#        '2021-Soutien', '2021-Esperance vie BS',
#        '2021-Liberte des choix de vie', '2021-Generosite', '2021-Corruption',
#        '2021-Dystopia + residual', '2022-Whisker-high', '2022-Whisker-low',
#        '2022-Dystopia + residual', '2022-Soutien', '2022-Esperance vie BS',
#        '2022-Liberte des choix de vie', '2022-Generosite', '2022-Corruption',
#        '_merge'],
#       dtype='object')

# %%
for i in range(2019, 2021, 1):
    df_light_merged['score_'+str(i)] = df_light_merged['score_'+str(i)].fillna(df_light_merged[str(i)])

# %%
df_light_merged.columns
# Out:
# Index(['country_official', 'country_origin', 'Regional indicator',
#        'country_FR', 'score_2015', 'score_2016', 'score_2017', 'score_2018',
#        '2019', 'score_2019', '2020', 'score_2020', '2021', '2022', '2019-rank',
#        '2019-Soutien', '2022-rank', '2019-PIB', '2020-PIB', '2022-PIB',
#        '2021-PIB', '2019-Esperance vie BS', '2019-Liberte des choix de vie',
#        '2019-Generosite', '2019-Corruption', '2020-Whisker-high',
#        '2020-Whisker-low', '2020-Soutien', '2020-Esperance vie BS',
#        '2020-Liberte des choix de vie', '2020-Generosite', '2020-Corruption',
#        '2020-Dystopia + residual', '2021-Whisker-high', '2021-Whisker-low',
#        '2021-Soutien', '2021-Esperance vie BS',
#        '2021-Liberte des choix de vie', '2021-Generosite', '2021-Corruption',
#        '2021-Dystopia + residual', '2022-Whisker-high', '2022-Whisker-low',
#        '2022-Dystopia + residual', '2022-Soutien', '2022-Esperance vie BS',
#        '2022-Liberte des choix de vie', '2022-Generosite', '2022-Corruption',
#        '_merge'],
#       dtype='object')

# %%
df_light_merged.loc[df_light_merged["_merge"]!="both", [ 'country_origin','country_FR', 'country_official', 'Regional indicator',
       'score_2015', 'score_2016', 'score_2017', 'score_2018', 'score_2019','2019',
       'score_2020',  '2020', '2021', '2022']]
# Out:
#                country_origin      country_FR          country_official  \
# 3                         NaN          Belize                    Belize
# 13       Eswatini. Kingdom of             NaN      Eswatini, Kingdom of
# 42                        NaN        Eswatini       Kingdom of Eswatini
# 73                        NaN          Angola        Republic of Angola
# 89            Northern Cyprus             NaN        Republic of Cyprus
# 90            Northern Cyprus             NaN        Republic of Cyprus
# 91            Northern Cyprus             NaN        Republic of Cyprus
# 92            Northern Cyprus             NaN        Republic of Cyprus
# 93            Northern Cyprus             NaN        Republic of Cyprus
# 94            Northern Cyprus             NaN        Republic of Cyprus
# 95            Northern Cyprus             NaN        Republic of Cyprus
# 96                     Cyprus             NaN        Republic of Cyprus
# 97                     Cyprus             NaN        Republic of Cyprus
# 98                     Cyprus             NaN        Republic of Cyprus
# 99                     Cyprus             NaN        Republic of Cyprus
# 100           Northern Cyprus             NaN        Republic of Cyprus
# 101                    Cyprus             NaN        Republic of Cyprus
# 102                    Cyprus             NaN        Republic of Cyprus
# 103                    Cyprus             NaN        Republic of Cyprus
# 104                    Cyprus             NaN        Republic of Cyprus
# 106                       NaN        Djibouti      Republic of Djibouti
# 147                       NaN        Suriname      Republic of Suriname
# 161                       NaN          Soudan     Republic of the Sudan
# 171                       NaN            Oman         Sultanate of Oman
# 175  Taiwan Province of China             NaN  Taiwan Province of China
# 177                       NaN          Chypre    The Republic of Cyprus
# 178                       NaN  Chypre du Nord    The Republic of Cyprus
#
#     Regional indicator  score_2015  score_2016  score_2017  score_2018  \
# 3                  NaN         NaN       5.956       5.956       5.956
# 13                 NaN         NaN         NaN         NaN         NaN
# 42                 NaN       4.867         NaN         NaN         NaN
# 73                 NaN       4.033       3.866       3.795       3.795
# 89      Western Europe         NaN         NaN         NaN         NaN
# 90      Western Europe         NaN         NaN         NaN         NaN
# 91      Western Europe         NaN         NaN         NaN         NaN
# 92      Western Europe         NaN         NaN         NaN         NaN
# 93      Western Europe         NaN         NaN         NaN         NaN
# 94      Western Europe         NaN         NaN         NaN         NaN
# 95      Western Europe         NaN         NaN         NaN         NaN
# 96      Western Europe         NaN         NaN         NaN         NaN
# 97      Western Europe         NaN         NaN         NaN         NaN
# 98      Western Europe         NaN         NaN         NaN         NaN
# 99      Western Europe         NaN         NaN         NaN         NaN
# 100     Western Europe         NaN         NaN         NaN         NaN
# 101     Western Europe         NaN         NaN         NaN         NaN
# 102     Western Europe         NaN         NaN         NaN         NaN
# 103     Western Europe         NaN         NaN         NaN         NaN
# 104     Western Europe         NaN         NaN         NaN         NaN
# 106                NaN       4.369         NaN         NaN         NaN
# 147                NaN       6.269       6.269         NaN         NaN
# 161                NaN       4.550       4.139       4.139       4.139
# 171                NaN       6.853         NaN         NaN         NaN
# 175          East Asia         NaN         NaN         NaN         NaN
# 177                NaN       5.689       5.546       5.621       5.762
# 178                NaN       5.695       5.771       5.810       5.835
#
#      score_2019   2019  score_2020   2020   2021   2022
# 3           NaN    NaN         NaN    NaN    NaN    NaN
# 13          NaN    NaN         NaN    NaN    NaN  4.396
# 42        4.212    NaN       4.308    NaN    NaN    NaN
# 73          NaN    NaN         NaN    NaN    NaN    NaN
# 89        5.718  5.718       5.536  5.536  6.223  5.467
# 90        5.718  5.718       6.159  6.159  5.536  5.467
# 91        5.718  5.718       6.159  6.159  5.536  6.221
# 92        5.718  5.718       5.536  5.536  6.223  6.221
# 93        5.718  5.718       6.159  6.159  6.223  6.221
# 94        5.718  5.718       6.159  6.159  6.223  5.467
# 95        5.718  5.718       5.536  5.536  5.536  5.467
# 96        6.046  6.046       5.536  5.536  6.223  6.221
# 97        6.046  6.046       5.536  5.536  5.536  5.467
# 98        6.046  6.046       5.536  5.536  5.536  6.221
# 99        6.046  6.046       5.536  5.536  6.223  5.467
# 100       5.718  5.718       5.536  5.536  5.536  6.221
# 101       6.046  6.046       6.159  6.159  5.536  5.467
# 102       6.046  6.046       6.159  6.159  6.223  5.467
# 103       6.046  6.046       6.159  6.159  6.223  6.221
# 104       6.046  6.046       6.159  6.159  5.536  6.221
# 106         NaN    NaN         NaN    NaN    NaN    NaN
# 147         NaN    NaN         NaN    NaN    NaN    NaN
# 161         NaN    NaN         NaN    NaN    NaN    NaN
# 171         NaN    NaN         NaN    NaN    NaN    NaN
# 175         NaN    NaN       6.455  6.455  6.584  6.512
# 177       6.046    NaN       6.159    NaN    NaN    NaN
# 178       5.718    NaN       5.536    NaN    NaN    NaN

# %% [markdown]
# Il y a 5 pays qui n'ont pas de score entre 2015 et 2020

# %%
print(df_light_merged.loc[df_light_merged["score_2019"] != df_light_merged["2019"],['country_origin', 'country_FR', 'country_official', 'Regional indicator','score_2019','2019']].shape)
df_light_merged.loc[df_light_merged["score_2019"] != df_light_merged["2019"],['country_origin', 'country_FR', 'country_official', 'Regional indicator','score_2019','2019']]
# Out:
# (17, 6)
#                country_origin      country_FR          country_official  \
# 3                         NaN          Belize                    Belize
# 13       Eswatini. Kingdom of             NaN      Eswatini, Kingdom of
# 42                        NaN        Eswatini       Kingdom of Eswatini
# 48                  Swaziland           Suède         Kingdom of Sweden
# 50                  Swaziland           Suède         Kingdom of Sweden
# 52                  Swaziland           Suède         Kingdom of Sweden
# 53                  Swaziland           Suède         Kingdom of Sweden
# 73                        NaN          Angola        Republic of Angola
# 106                       NaN        Djibouti      Republic of Djibouti
# 127                  Maldives        Maldives      Republic of Maldives
# 147                       NaN        Suriname      Republic of Suriname
# 161                       NaN          Soudan     Republic of the Sudan
# 168                    Kuwait          Koweït           State of Kuwait
# 171                       NaN            Oman         Sultanate of Oman
# 175  Taiwan Province of China             NaN  Taiwan Province of China
# 177                       NaN          Chypre    The Republic of Cyprus
# 178                       NaN  Chypre du Nord    The Republic of Cyprus
#
#                Regional indicator  score_2019   2019
# 3                             NaN         NaN    NaN
# 13                            NaN         NaN    NaN
# 42                            NaN       4.212    NaN
# 48                 Western Europe       7.343  4.212
# 50                 Western Europe       7.343  4.212
# 52             Sub-Saharan Africa       7.343  4.212
# 53             Sub-Saharan Africa       7.343  4.212
# 73                            NaN         NaN    NaN
# 106                           NaN         NaN    NaN
# 127                    South Asia         NaN    NaN
# 147                           NaN         NaN    NaN
# 161                           NaN         NaN    NaN
# 168  Middle East and North Africa       6.011  6.021
# 171                           NaN         NaN    NaN
# 175                     East Asia         NaN    NaN
# 177                           NaN       6.046    NaN
# 178                           NaN       5.718    NaN

# %%
print(df_light_merged.loc[df_light_merged["score_2020"] != df_light_merged["2020"],['country_origin', 'country_FR', 'country_official', 'Regional indicator','score_2020', '2020']].shape)
df_light_merged.loc[df_light_merged["score_2020"] != df_light_merged["2020"],['country_origin', 'country_FR', 'country_official', 'Regional indicator','score_2020', '2020']]
# Out:
# (20, 6)
#            country_origin      country_FR             country_official  \
# 3                     NaN          Belize                       Belize
# 13   Eswatini. Kingdom of             NaN         Eswatini, Kingdom of
# 18                Somalia         Somalie  Federal Republic of Somalia
# 19                Somalia      Somaliland  Federal Republic of Somalia
# 39                 Bhutan         Bhoutan            Kingdom of Bhutan
# 42                    NaN        Eswatini          Kingdom of Eswatini
# 49                 Sweden           Suède            Kingdom of Sweden
# 52              Swaziland           Suède            Kingdom of Sweden
# 53              Swaziland           Suède            Kingdom of Sweden
# 54                 Sweden           Suède            Kingdom of Sweden
# 73                    NaN          Angola           Republic of Angola
# 106                   NaN        Djibouti         Republic of Djibouti
# 147                   NaN        Suriname         Republic of Suriname
# 161                   NaN          Soudan        Republic of the Sudan
# 170                 Qatar           Qatar               State of Qatar
# 171                   NaN            Oman            Sultanate of Oman
# 173                 Syria           Syrie                        Syria
# 174                Taiwan          Taïwan                       Taiwan
# 177                   NaN          Chypre       The Republic of Cyprus
# 178                   NaN  Chypre du Nord       The Republic of Cyprus
#
#      Regional indicator  score_2020   2020
# 3                   NaN         NaN    NaN
# 13                  NaN         NaN    NaN
# 18                  NaN         NaN    NaN
# 19                  NaN         NaN    NaN
# 39                  NaN         NaN    NaN
# 42                  NaN       4.308    NaN
# 49   Sub-Saharan Africa       7.353  4.308
# 52   Sub-Saharan Africa       7.353  4.308
# 53   Sub-Saharan Africa       7.353  4.308
# 54   Sub-Saharan Africa       7.353  4.308
# 73                  NaN         NaN    NaN
# 106                 NaN         NaN    NaN
# 147                 NaN         NaN    NaN
# 161                 NaN         NaN    NaN
# 170                 NaN         NaN    NaN
# 171                 NaN         NaN    NaN
# 173                 NaN         NaN    NaN
# 174                 NaN       6.455    NaN
# 177                 NaN       6.159    NaN
# 178                 NaN       5.536    NaN

# %%
df_light_merged.loc[df_light_merged["score_2019"] != df_light_merged["2019"],['country_origin', 'country_FR', 'country_official', 'Regional indicator',
       'score_2019','2019','score_2020', '2020']].shape
# Out:
# (17, 8)

# %%
print(f"2019 : {df_light_merged['2019'].isna().sum()} NA")
print(f"2020 : {df_light_merged['2020'].isna().sum()} NA")
# Out:
# 2019 : 9 NA
# 2020 : 16 NA

# %%
print(f"2019 : {df_light_merged['2019'].isna().sum()} NA")
print(f"2020 : {df_light_merged['2020'].isna().sum()} NA")
df_light_merged["2019"] = df_light_merged["2019"].fillna(df_light_merged["score_2019"])
df_light_merged["2020"] = df_light_merged["2020"].fillna(df_light_merged["score_2020"])
print(f"2019 : {df_light_merged['2019'].isna().sum()} NA")
print(f"2020 : {df_light_merged['2020'].isna().sum()} NA")

# %%
print(f"2019 : {df_light_merged['2019'].isna().sum()} NA")
print(f"2020 : {df_light_merged['2020'].isna().sum()} NA")
# Out:
# 2019 : 9 NA
# 2020 : 12 NA

# %%
to_drop_filter = (df_light_merged["_merge"] == "right_only") & (df_light_merged["2019"].isna()) & (df_light_merged["2020"].isna()) & (df_light_merged["2021"].isna()) & (df_light_merged["2022"].isna())

# %%
# Suppression des lignes qui n'ont pas de données pour les dernières années
df_light_merged_clean = df_light_merged[~to_drop_filter]
print(f"{df_light_merged.shape} => {df_light_merged_clean.shape}")
# Out:
# (190, 50) => (184, 50)

# %%
df_light_merged_clean.loc[df_light_merged_clean["_merge"] != "both", ['country_official', 'country_origin', 
       'country_FR', 'score_2015', 'score_2016', 'score_2017', 'score_2018',
       '2019', 'score_2019', '2020', 'score_2020', '2021', '2022', 
       '_merge']]
# Out:
#              country_official            country_origin      country_FR  \
# 13       Eswatini, Kingdom of      Eswatini. Kingdom of             NaN
# 42        Kingdom of Eswatini                       NaN        Eswatini
# 89         Republic of Cyprus           Northern Cyprus             NaN
# 90         Republic of Cyprus           Northern Cyprus             NaN
# 91         Republic of Cyprus           Northern Cyprus             NaN
# 92         Republic of Cyprus           Northern Cyprus             NaN
# 93         Republic of Cyprus           Northern Cyprus             NaN
# 94         Republic of Cyprus           Northern Cyprus             NaN
# 95         Republic of Cyprus           Northern Cyprus             NaN
# 96         Republic of Cyprus                    Cyprus             NaN
# 97         Republic of Cyprus                    Cyprus             NaN
# 98         Republic of Cyprus                    Cyprus             NaN
# 99         Republic of Cyprus                    Cyprus             NaN
# 100        Republic of Cyprus           Northern Cyprus             NaN
# 101        Republic of Cyprus                    Cyprus             NaN
# 102        Republic of Cyprus                    Cyprus             NaN
# 103        Republic of Cyprus                    Cyprus             NaN
# 104        Republic of Cyprus                    Cyprus             NaN
# 175  Taiwan Province of China  Taiwan Province of China             NaN
# 177    The Republic of Cyprus                       NaN          Chypre
# 178    The Republic of Cyprus                       NaN  Chypre du Nord
#
#      score_2015  score_2016  score_2017  score_2018   2019  score_2019   2020  \
# 13          NaN         NaN         NaN         NaN    NaN         NaN    NaN
# 42        4.867         NaN         NaN         NaN  4.212       4.212  4.308
# 89          NaN         NaN         NaN         NaN  5.718       5.718  5.536
# 90          NaN         NaN         NaN         NaN  5.718       5.718  6.159
# 91          NaN         NaN         NaN         NaN  5.718       5.718  6.159
# 92          NaN         NaN         NaN         NaN  5.718       5.718  5.536
# 93          NaN         NaN         NaN         NaN  5.718       5.718  6.159
# 94          NaN         NaN         NaN         NaN  5.718       5.718  6.159
# 95          NaN         NaN         NaN         NaN  5.718       5.718  5.536
# 96          NaN         NaN         NaN         NaN  6.046       6.046  5.536
# 97          NaN         NaN         NaN         NaN  6.046       6.046  5.536
# 98          NaN         NaN         NaN         NaN  6.046       6.046  5.536
# 99          NaN         NaN         NaN         NaN  6.046       6.046  5.536
# 100         NaN         NaN         NaN         NaN  5.718       5.718  5.536
# 101         NaN         NaN         NaN         NaN  6.046       6.046  6.159
# 102         NaN         NaN         NaN         NaN  6.046       6.046  6.159
# 103         NaN         NaN         NaN         NaN  6.046       6.046  6.159
# 104         NaN         NaN         NaN         NaN  6.046       6.046  6.159
# 175         NaN         NaN         NaN         NaN    NaN         NaN  6.455
# 177       5.689       5.546       5.621       5.762  6.046       6.046  6.159
# 178       5.695       5.771       5.810       5.835  5.718       5.718  5.536
#
#      score_2020   2021   2022      _merge
# 13          NaN    NaN  4.396   left_only
# 42        4.308    NaN    NaN  right_only
# 89        5.536  6.223  5.467   left_only
# 90        6.159  5.536  5.467   left_only
# 91        6.159  5.536  6.221   left_only
# 92        5.536  6.223  6.221   left_only
# 93        6.159  6.223  6.221   left_only
# 94        6.159  6.223  5.467   left_only
# 95        5.536  5.536  5.467   left_only
# 96        5.536  6.223  6.221   left_only
# 97        5.536  5.536  5.467   left_only
# 98        5.536  5.536  6.221   left_only
# 99        5.536  6.223  5.467   left_only
# 100       5.536  5.536  6.221   left_only
# 101       6.159  5.536  5.467   left_only
# 102       6.159  6.223  5.467   left_only
# 103       6.159  6.223  6.221   left_only
# 104       6.159  5.536  6.221   left_only
# 175       6.455  6.584  6.512   left_only
# 177       6.159    NaN    NaN  right_only
# 178       5.536    NaN    NaN  right_only

# %%
y = "2019"
y2 = "score_"+y
cols = list(df_light_merged_clean.columns)
cols.remove(y)
cols.remove(y2)
cols.insert(3, y)
cols.insert(4, y2)
df_light_merged_clean.loc[(df_light_merged_clean[y] != df_light_merged_clean[y2]) & (df_light_merged_clean[y].notna()),cols]
# Out:
#       country_official country_origin            Regional indicator   2019  \
# 48   Kingdom of Sweden      Swaziland                Western Europe  4.212
# 50   Kingdom of Sweden      Swaziland                Western Europe  4.212
# 52   Kingdom of Sweden      Swaziland            Sub-Saharan Africa  4.212
# 53   Kingdom of Sweden      Swaziland            Sub-Saharan Africa  4.212
# 168    State of Kuwait         Kuwait  Middle East and North Africa  6.021
#
#      score_2019 country_FR  score_2015  score_2016  score_2017  score_2018  \
# 48        7.343      Suède       7.364       7.291       7.284       7.314
# 50        7.343      Suède       7.364       7.291       7.284       7.314
# 52        7.343      Suède       7.364       7.291       7.284       7.314
# 53        7.343      Suède       7.364       7.291       7.284       7.314
# 168       6.011     Koweït       6.295       6.239       6.105       6.083
#
#      ...  2021-Dystopia + residual  2022-Whisker-high  2022-Whisker-low  \
# 48   ...                     2.683              7.454             7.315
# 50   ...                     2.155              7.454             7.315
# 52   ...                     2.155              7.454             7.315
# 53   ...                     2.683              7.454             7.315
# 168  ...                     2.368              6.235             5.977
#
#      2022-Dystopia + residual  2022-Soutien  2022-Esperance vie BS  \
# 48                      2.003         1.204                  0.803
# 50                      2.003         1.204                  0.803
# 52                      2.003         1.204                  0.803
# 53                      2.003         1.204                  0.803
# 168                     1.621         0.983                  0.747
#
#      2022-Liberte des choix de vie  2022-Generosite  2022-Corruption  _merge
# 48                           0.724            0.218            0.512    both
# 50                           0.724            0.218            0.512    both
# 52                           0.724            0.218            0.512    both
# 53                           0.724            0.218            0.512    both
# 168                          0.617            0.087            0.147    both
#
# [5 rows x 50 columns]

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### 2.2.2. Fusion dataset intermédiaire et données pays
# </div>

# %%
df_light_merged_clean.columns
# Out:
# Index(['country_official', 'country_origin', 'Regional indicator',
#        'country_FR', 'score_2015', 'score_2016', 'score_2017', 'score_2018',
#        '2019', 'score_2019', '2020', 'score_2020', '2021', '2022', '2019-rank',
#        '2019-Soutien', '2022-rank', '2019-PIB', '2020-PIB', '2022-PIB',
#        '2021-PIB', '2019-Esperance vie BS', '2019-Liberte des choix de vie',
#        '2019-Generosite', '2019-Corruption', '2020-Whisker-high',
#        '2020-Whisker-low', '2020-Soutien', '2020-Esperance vie BS',
#        '2020-Liberte des choix de vie', '2020-Generosite', '2020-Corruption',
#        '2020-Dystopia + residual', '2021-Whisker-high', '2021-Whisker-low',
#        '2021-Soutien', '2021-Esperance vie BS',
#        '2021-Liberte des choix de vie', '2021-Generosite', '2021-Corruption',
#        '2021-Dystopia + residual', '2022-Whisker-high', '2022-Whisker-low',
#        '2022-Dystopia + residual', '2022-Soutien', '2022-Esperance vie BS',
#        '2022-Liberte des choix de vie', '2022-Generosite', '2022-Corruption',
#        '_merge'],
#       dtype='object')

# %%
print(f"ORIGIN : {df_light_merged.shape}, {df_pays_origin.shape}, AFTER ", end="")
df_global = df_light_merged.merge(df_pays_origin, on='country_official', how="left", indicator=True)
print(df_global.shape)
df_global.head()
# Out:
# ORIGIN : (190, 50), (213, 8), AFTER
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\User\WORK\workspace-ia\PROJETS\projet_bonheur_bed\projet_bonheur_bed_ara.ipynb Cell 56' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/User/WORK/workspace-ia/PROJETS/projet_bonheur_bed/projet_bonheur_bed_ara.ipynb#ch0000062?line=0'>1</a> print(f"ORIGIN : {df_light_merged.shape}, {df_pays_origin.shape}, AFTER ", end="")
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/WORK/workspace-ia/PROJETS/projet_bonheur_bed/projet_bonheur_bed_ara.ipynb#ch0000062?line=1'>2</a> df_global = df_light_merged.merge(df_pays_origin, on='country_official', how="left", indicator=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/User/WORK/workspace-ia/PROJETS/projet_bonheur_bed/projet_bonheur_bed_ara.ipynb#ch0000062?line=2'>3</a> print(df_global.shape)
#       <a href='vscode-notebook-cell:/c%3A/Users/User/WORK/workspace-ia/PROJETS/projet_bonheur_bed/projet_bonheur_bed_ara.ipynb#ch0000062?line=3'>4</a> df_global.head()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:9329, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=9309'>9310</a> @Substitution("")
#    <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=9310'>9311</a> @Appender(_merge_doc, indents=2)
#    <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=9311'>9312</a> def merge(
#    (...)
#    <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=9324'>9325</a>     validate: str | None = None,
#    <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=9325'>9326</a> ) -> DataFrame:
#    <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=9326'>9327</a>     from pandas.core.reshape.merge import merge
# -> <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=9328'>9329</a>     return merge(
#    <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=9329'>9330</a>         self,
#    <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=9330'>9331</a>         right,
#    <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=9331'>9332</a>         how=how,
#    <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=9332'>9333</a>         on=on,
#    <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=9333'>9334</a>         left_on=left_on,
#    <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=9334'>9335</a>         right_on=right_on,
#    <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=9335'>9336</a>         left_index=left_index,
#    <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=9336'>9337</a>         right_index=right_index,
#    <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=9337'>9338</a>         sort=sort,
#    <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=9338'>9339</a>         suffixes=suffixes,
#    <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=9339'>9340</a>         copy=copy,
#    <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=9340'>9341</a>         indicator=indicator,
#    <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=9341'>9342</a>         validate=validate,
#    <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/frame.py?line=9342'>9343</a>     )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\merge.py:122, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=89'>90</a> @Substitution("\nleft : DataFrame or named Series")
#      <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=90'>91</a> @Appender(_merge_doc, indents=0)
#      <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=91'>92</a> def merge(
#    (...)
#     <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=104'>105</a>     validate: str | None = None,
#     <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=105'>106</a> ) -> DataFrame:
#     <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=106'>107</a>     op = _MergeOperation(
#     <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=107'>108</a>         left,
#     <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=108'>109</a>         right,
#    (...)
#     <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=119'>120</a>         validate=validate,
#     <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=120'>121</a>     )
# --> <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=121'>122</a>     return op.get_result()
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\merge.py:714, in _MergeOperation.get_result(self)
#     <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=711'>712</a> def get_result(self) -> DataFrame:
#     <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=712'>713</a>     if self.indicator:
# --> <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=713'>714</a>         self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=715'>716</a>     join_index, left_indexer, right_indexer = self._get_join_info()
#     <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=717'>718</a>     llabels, rlabels = _items_overlap_with_suffix(
#     <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=718'>719</a>         self.left._info_axis, self.right._info_axis, self.suffixes
#     <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=719'>720</a>     )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\reshape\merge.py:765, in _MergeOperation._indicator_pre_merge(self, left, right)
#     <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=759'>760</a>         raise ValueError(
#     <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=760'>761</a>             "Cannot use `indicator=True` option when "
#     <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=761'>762</a>             f"data contains a column named {i}"
#     <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=762'>763</a>         )
#     <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=763'>764</a> if self.indicator_name in columns:
# --> <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=764'>765</a>     raise ValueError(
#     <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=765'>766</a>         "Cannot use name of an existing column for indicator column"
#     <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=766'>767</a>     )
#     <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=768'>769</a> left = left.copy()
#     <a href='file:///c%3A/Users/User/AppData/Roaming/Python/Python39/site-packages/pandas/core/reshape/merge.py?line=769'>770</a> right = right.copy()
#
# ValueError: Cannot use name of an existing column for indicator column

# %%
df_global[df_global["_merge"]!="both"]

# %% [markdown]
# <div style="display: flex; background-color: green;" >
#
# ### 2.X. Chargement des autres sources de données
# </div>

# %%
dic_world_df = {}
for file_name in world_datas_files:
    df_temp = pd.read_csv(data_set_path+file_name, sep=',')
    print(f"{file_name}{df_temp.shape} : {df_temp.columns}")
    dic_world_df[file_name] = df_temp

print(dic_world_df.keys)

# %% [markdown]
# <div style="display: flex; background-color: Blue; padding: 15px;" >
#
# # 3.Exploration des données
# </div>

# %%
the_df = df_light_merged_clean.copy()
the_df_by_line = df_light_completed_by_line.copy()

# %% [markdown]
# <div style="display: flex; background-color: green;" >
#
# ## 1.1. Visualisation des données
# </div>

# %%
print(the_df.shape)
print(the_df_by_line.shape)

# %%
the_df.head()

# %%
the_df_by_line.head()

# %%
the_df.dtypes

# %%
the_df_by_line.dtypes

# %%
the_df.describe(include="all")

# %%
the_df_by_line.describe(include="all")

# %%
the_df.hist(figsize=(25,25),bins=50)

# %%
the_df_by_line.hist(figsize=(25,25),bins=50)

# %% [markdown]
# <div style="display: flex; background-color: green;" >
#
# ## 1.2. Analyse des NaN
# </div>

# %%
sns.heatmap(the_df.isnull(), yticklabels=False,cbar=False, cmap='viridis')

# %%
msno.heatmap(the_df)

# %%
# Avant nettoyage
msno.matrix(the_df)

# %%
msno.bar(the_df)

# %% [markdown]
# <div style="display: flex; background-color: green;" >
#
# ## 1.2. Corrélations entre les données
# </div>

# %%
df_origine["score_int"] = round(df_origine["Score"])
df_origine["score_int"] = df_origine["score_int"].astype('int')

# %%
sns.pairplot(df_origine, hue="score_int")

# %%
draw_correlation_graphe(df_origine, "Corrélation entre les variables", verbose=verbose,fontsize=12)

# %% [markdown]
# <div style="display: flex; background-color: green;" >
#
# ## 1.3. Visualisation des outliers
# </div>

# %%
cols = get_numeric_columns_names(df_origine)
for column_name in cols:
    q_low, q_hi,iqr, q_min, q_max = get_outliers_datas(df_origine, column_name)
    graphe_outliers(df_origine, column_name, q_min, q_max)

# %% [markdown]
# <div style="display: flex; background-color: green;" >
#
# ## 1.4. Analyse des autres doublons possible
# </div>

# %% [markdown]
# # Chargement DF pays

# %%
pays_file_name = "data_set_countries_clean.csv"

# %% [markdown]
# <div style="display: flex; background-color: Blue; padding: 15px;" >
#
# ## Annexes
# </div>

# %%
just to fail

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### Titre 2
# </div>

# %% [markdown]
# <div style="display: flex; background-color: indigo;" >
#
# #### Titre 3
# </div>

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### Nettoyage des pays par année dans la DF
# </div>

# %%
diff = df_origine_light[df_origine_light["2019-country_origin"] != df_origine_light["2019-country"]]
diff = diff[['country_official', 'Regional indicator', '2019-country_origin','2019-country',
       '2020-country_origin', '2020-country', '2021-country_origin', '2021-country', '2022-country_origin', '2022-country' ]]
print(diff[diff["2019-country"].notna()].shape)
diff[diff["2019-country"].notna()]
# Out:
# (6, 10)
#                                      country_official  \
# 8                    Democratic Republic Of The Congo
# 24   Hong Kong Special Administrative Region of China
# 40                                Kingdom of Eswatini
# 119                   Republic of Trinidad and Tobago
# 127                             Republic of the Congo
# 131                             Republic of the Sudan
#
#               Regional indicator  2019-country_origin  \
# 8             Sub-Saharan Africa     Congo (Kinshasa)
# 24                     East Asia            Hong Kong
# 40            Sub-Saharan Africa            Swaziland
# 119  Latin America and Caribbean    Trinidad & Tobago
# 127           Sub-Saharan Africa  Congo (Brazzaville)
# 131           Sub-Saharan Africa          South Sudan
#
#                          2019-country        2020-country_origin  \
# 8    Democratic Republic of the Congo           Congo (Kinshasa)
# 24          Hong Kong S.A.R. of China  Hong Kong S.A.R. of China
# 40                           Eswatini                  Swaziland
# 119               Trinidad and Tobago        Trinidad and Tobago
# 127             Republic of the Congo        Congo (Brazzaville)
# 131                             Sudan                South Sudan
#
#                          2020-country        2021-country_origin  \
# 8    Democratic Republic of the Congo                        NaN
# 24          Hong Kong S.A.R. of China  Hong Kong S.A.R. of China
# 40                           Eswatini                  Swaziland
# 119               Trinidad and Tobago                        NaN
# 127             Republic of the Congo        Congo (Brazzaville)
# 131                             Sudan                        NaN
#
#                   2021-country        2022-country_origin  \
# 8                          NaN                        NaN
# 24   Hong Kong S.A.R. of China  Hong Kong S.A.R. of China
# 40                    Eswatini       Eswatini. Kingdom of
# 119                        NaN                        NaN
# 127      Republic of the Congo                      Congo
# 131                        NaN                        NaN
#
#                   2022-country
# 8                          NaN
# 24   Hong Kong S.A.R. of China
# 40                    Eswatini
# 119                        NaN
# 127                      Congo
# 131                        NaN

# %%
diff = df_origine_light[df_origine_light["2019-country_origin"] != df_origine_light["2020-country_origin"]]
diff = diff[['country_official', 'Regional indicator', '2019-country_origin',
       '2020-country_origin', '2019-country','2020-country', '2021-country_origin', '2021-country', '2022-country_origin', '2022-country' ]]
print(diff[diff["2019-country_origin"].notna() & diff["2020-country_origin"].notna()].shape)
diff[diff["2019-country_origin"].notna() & diff["2020-country_origin"].notna()]
# Out:
# (4, 10)
#                                      country_official  \
# 24   Hong Kong Special Administrative Region of China
# 107                       Republic of North Macedonia
# 119                   Republic of Trinidad and Tobago
# 145                            The Republic of Cyprus
#
#               Regional indicator 2019-country_origin  \
# 24                     East Asia           Hong Kong
# 107   Central and Eastern Europe     North Macedonia
# 119  Latin America and Caribbean   Trinidad & Tobago
# 145               Western Europe     Northern Cyprus
#
#            2020-country_origin               2019-country  \
# 24   Hong Kong S.A.R. of China  Hong Kong S.A.R. of China
# 107                  Macedonia            North Macedonia
# 119        Trinidad and Tobago        Trinidad and Tobago
# 145               North Cyprus            Northern Cyprus
#
#                   2020-country        2021-country_origin  \
# 24   Hong Kong S.A.R. of China  Hong Kong S.A.R. of China
# 107                  Macedonia            North Macedonia
# 119        Trinidad and Tobago                        NaN
# 145            Northern Cyprus               North Cyprus
#
#                   2021-country        2022-country_origin  \
# 24   Hong Kong S.A.R. of China  Hong Kong S.A.R. of China
# 107            North Macedonia            North Macedonia
# 119                        NaN                        NaN
# 145            Northern Cyprus               North Cyprus
#
#                   2022-country
# 24   Hong Kong S.A.R. of China
# 107            North Macedonia
# 119                        NaN
# 145            Northern Cyprus

# %%
diff = df_origine_light[df_origine_light["2020-country_origin"] != df_origine_light["2021-country_origin"]]
diff = diff[['country_official', 'Regional indicator', 
       '2020-country_origin', '2021-country_origin', '2020-country', '2021-country', '2022-country_origin', '2022-country' ]]
print(diff[diff["2020-country_origin"].notna() & diff["2021-country_origin"].notna()].shape)
diff[diff["2020-country_origin"].notna() & diff["2021-country_origin"].notna()]
# Out:
# (1, 8)
#                 country_official          Regional indicator  \
# 107  Republic of North Macedonia  Central and Eastern Europe
#
#     2020-country_origin 2021-country_origin 2020-country     2021-country  \
# 107           Macedonia     North Macedonia    Macedonia  North Macedonia
#
#     2022-country_origin     2022-country
# 107     North Macedonia  North Macedonia

# %%
diff = df_origine_light[df_origine_light["2021-country_origin"] != df_origine_light["2022-country_origin"]]
diff = diff[['country_official', 'Regional indicator', 
       '2021-country_origin', '2022-country_origin', '2021-country', '2022-country' ]]
print(diff[diff["2021-country_origin"].notna() & diff["2022-country_origin"].notna()].shape)
diff[diff["2021-country_origin"].notna() & diff["2022-country_origin"].notna()]
# Out:
# (3, 6)
#           country_official          Regional indicator  2021-country_origin  \
# 7           Czech Republic  Central and Eastern Europe       Czech Republic
# 40     Kingdom of Eswatini          Sub-Saharan Africa            Swaziland
# 127  Republic of the Congo          Sub-Saharan Africa  Congo (Brazzaville)
#
#       2022-country_origin           2021-country    2022-country
# 7                 Czechia         Czech Republic  Czech Republic
# 40   Eswatini. Kingdom of               Eswatini        Eswatini
# 127                 Congo  Republic of the Congo           Congo

# %%
diff = df_origine_light[df_origine_light["2020-country_origin"] != df_origine_light["2020-country"]]
diff = diff[['country_official', 'Regional indicator', '2019-country_origin','2019-country',
       '2020-country_origin', '2020-country', '2021-country_origin', '2021-country', '2022-country_origin', '2022-country' ]]
print(diff[diff["2020-country"].notna()].shape)
diff[diff["2020-country"].notna()]
# Out:
# (6, 10)
#                      country_official  Regional indicator  \
# 8    Democratic Republic Of The Congo  Sub-Saharan Africa
# 40                Kingdom of Eswatini  Sub-Saharan Africa
# 156                 Republic of China           East Asia
# 127             Republic of the Congo  Sub-Saharan Africa
# 131             Republic of the Sudan  Sub-Saharan Africa
# 145            The Republic of Cyprus      Western Europe
#
#      2019-country_origin                      2019-country  \
# 8       Congo (Kinshasa)  Democratic Republic of the Congo
# 40             Swaziland                          Eswatini
# 156                  NaN                               NaN
# 127  Congo (Brazzaville)             Republic of the Congo
# 131          South Sudan                             Sudan
# 145      Northern Cyprus                   Northern Cyprus
#
#           2020-country_origin                      2020-country  \
# 8            Congo (Kinshasa)  Democratic Republic of the Congo
# 40                  Swaziland                          Eswatini
# 156  Taiwan Province of China                 Republic of China
# 127       Congo (Brazzaville)             Republic of the Congo
# 131               South Sudan                             Sudan
# 145              North Cyprus                   Northern Cyprus
#
#           2021-country_origin           2021-country  \
# 8                         NaN                    NaN
# 40                  Swaziland               Eswatini
# 156  Taiwan Province of China      Republic of China
# 127       Congo (Brazzaville)  Republic of the Congo
# 131                       NaN                    NaN
# 145              North Cyprus        Northern Cyprus
#
#           2022-country_origin       2022-country
# 8                         NaN                NaN
# 40       Eswatini. Kingdom of           Eswatini
# 156  Taiwan Province of China  Republic of China
# 127                     Congo              Congo
# 131                       NaN                NaN
# 145              North Cyprus    Northern Cyprus

# %%
diff = df_origine_light_completed2[df_origine_light_completed2["2020-country_origin"] != df_origine_light_completed2["country_origin"]]
diff = diff[['country_official', 'Regional indicator', 'country_origin','country',
       '2020-country_origin' ]]
diff
# Out:
#                                      country_official  \
# 16                        Federal Republic of Somalia
# 24   Hong Kong Special Administrative Region of China
# 37                                  Kingdom of Bhutan
# 107                       Republic of North Macedonia
# 119                   Republic of Trinidad and Tobago
# 140                                    State of Qatar
# 142                                             Syria
# 143                                            Taiwan
# 145                            The Republic of Cyprus
#
#               Regional indicator     country_origin  \
# 16                           NaN            Somalia
# 24                     East Asia          Hong Kong
# 37                           NaN             Bhutan
# 107   Central and Eastern Europe    North Macedonia
# 119  Latin America and Caribbean  Trinidad & Tobago
# 140                          NaN              Qatar
# 142                          NaN              Syria
# 143                          NaN             Taiwan
# 145               Western Europe    Northern Cyprus
#
#                        country        2020-country_origin
# 16                     Somalia                        NaN
# 24   Hong Kong S.A.R. of China  Hong Kong S.A.R. of China
# 37                      Bhutan                        NaN
# 107            North Macedonia                  Macedonia
# 119        Trinidad and Tobago        Trinidad and Tobago
# 140                      Qatar                        NaN
# 142                      Syria                        NaN
# 143                     Taiwan                        NaN
# 145            Northern Cyprus               North Cyprus

# %%
try:
    df_origine_light_completed2 = df_origine_light_completed2.drop("2020-country_origin", axis=1)
except:
    pass
diff = df_origine_light_completed2[df_origine_light_completed2["2021-country_origin"] != df_origine_light_completed2["country_origin"]]
diff = diff[['country_official', 'Regional indicator', 'country_origin','country',
       '2021-country_origin' ]]
diff
# Out:
#                                      country_official  \
# 6                            Central African Republic
# 8                    Democratic Republic Of The Congo
# 16                        Federal Republic of Somalia
# 24   Hong Kong Special Administrative Region of China
# 37                                  Kingdom of Bhutan
# 119                   Republic of Trinidad and Tobago
# 131                             Republic of the Sudan
# 140                                    State of Qatar
# 142                                             Syria
# 143                                            Taiwan
# 145                            The Republic of Cyprus
#
#               Regional indicator            country_origin  \
# 6             Sub-Saharan Africa  Central African Republic
# 8             Sub-Saharan Africa          Congo (Kinshasa)
# 16                           NaN                   Somalia
# 24                     East Asia                 Hong Kong
# 37                           NaN                    Bhutan
# 119  Latin America and Caribbean         Trinidad & Tobago
# 131           Sub-Saharan Africa               South Sudan
# 140                          NaN                     Qatar
# 142                          NaN                     Syria
# 143                          NaN                    Taiwan
# 145               Western Europe           Northern Cyprus
#
#                               country        2021-country_origin
# 6            Central African Republic                        NaN
# 8    Democratic Republic of the Congo                        NaN
# 16                            Somalia                        NaN
# 24          Hong Kong S.A.R. of China  Hong Kong S.A.R. of China
# 37                             Bhutan                        NaN
# 119               Trinidad and Tobago                        NaN
# 131                             Sudan                        NaN
# 140                             Qatar                        NaN
# 142                             Syria                        NaN
# 143                            Taiwan                        NaN
# 145                   Northern Cyprus               North Cyprus

# %%
try:
    df_origine_light_completed2 = df_origine_light_completed2.drop("2021-country_origin", axis=1)
except:
    pass
diff = df_origine_light_completed2[df_origine_light_completed2["2022-country_origin"] != df_origine_light_completed2["country_origin"]]
diff = diff[['country_official', 'Regional indicator', 'country_origin','country',
       '2022-country_origin' ]]
diff
# Out:
#                                      country_official  \
# 6                            Central African Republic
# 7                                      Czech Republic
# 8                    Democratic Republic Of The Congo
# 16                        Federal Republic of Somalia
# 24   Hong Kong Special Administrative Region of China
# 37                                  Kingdom of Bhutan
# 40                                Kingdom of Eswatini
# 72                                Republic of Burundi
# 87                                  Republic of Haiti
# 157                              Republic of Maldives
# 119                   Republic of Trinidad and Tobago
# 127                             Republic of the Congo
# 131                             Republic of the Sudan
# 140                                    State of Qatar
# 142                                             Syria
# 143                                            Taiwan
# 145                            The Republic of Cyprus
#
#               Regional indicator            country_origin  \
# 6             Sub-Saharan Africa  Central African Republic
# 7     Central and Eastern Europe            Czech Republic
# 8             Sub-Saharan Africa          Congo (Kinshasa)
# 16                           NaN                   Somalia
# 24                     East Asia                 Hong Kong
# 37                           NaN                    Bhutan
# 40            Sub-Saharan Africa                 Swaziland
# 72            Sub-Saharan Africa                   Burundi
# 87   Latin America and Caribbean                     Haiti
# 157                   South Asia                  Maldives
# 119  Latin America and Caribbean         Trinidad & Tobago
# 127           Sub-Saharan Africa       Congo (Brazzaville)
# 131           Sub-Saharan Africa               South Sudan
# 140                          NaN                     Qatar
# 142                          NaN                     Syria
# 143                          NaN                    Taiwan
# 145               Western Europe           Northern Cyprus
#
#                               country        2022-country_origin
# 6            Central African Republic                        NaN
# 7                      Czech Republic                    Czechia
# 8    Democratic Republic of the Congo                        NaN
# 16                            Somalia                        NaN
# 24          Hong Kong S.A.R. of China  Hong Kong S.A.R. of China
# 37                             Bhutan                        NaN
# 40                           Eswatini       Eswatini. Kingdom of
# 72                            Burundi                        NaN
# 87                              Haiti                        NaN
# 157                          Maldives                        NaN
# 119               Trinidad and Tobago                        NaN
# 127             Republic of the Congo                      Congo
# 131                             Sudan                        NaN
# 140                             Qatar                        NaN
# 142                             Syria                        NaN
# 143                            Taiwan                        NaN
# 145                   Northern Cyprus               North Cyprus

# %%
col = "2020-country"
diff = df_origine_light_completed2[df_origine_light_completed2[col] != df_origine_light_completed2["country"]]
diff = diff[['country_official', 'Regional indicator', 'country_origin','country', col ]]
diff
# Out:
#                 country_official          Regional indicator   country_origin  \
# 16   Federal Republic of Somalia                         NaN          Somalia
# 37             Kingdom of Bhutan                         NaN           Bhutan
# 107  Republic of North Macedonia  Central and Eastern Europe  North Macedonia
# 140               State of Qatar                         NaN            Qatar
# 142                        Syria                         NaN            Syria
# 143                       Taiwan                         NaN           Taiwan
#
#              country 2020-country
# 16           Somalia          NaN
# 37            Bhutan          NaN
# 107  North Macedonia    Macedonia
# 140            Qatar          NaN
# 142            Syria          NaN
# 143           Taiwan          NaN

# %%
col = "2021-country"
diff = df_origine_light_completed2[df_origine_light_completed2[col] != df_origine_light_completed2["country"]]
diff = diff[['country_official', 'Regional indicator', 'country_origin','country', col ]]
diff
# Out:
#                      country_official           Regional indicator  \
# 6            Central African Republic           Sub-Saharan Africa
# 8    Democratic Republic Of The Congo           Sub-Saharan Africa
# 16        Federal Republic of Somalia                          NaN
# 37                  Kingdom of Bhutan                          NaN
# 119   Republic of Trinidad and Tobago  Latin America and Caribbean
# 131             Republic of the Sudan           Sub-Saharan Africa
# 140                    State of Qatar                          NaN
# 142                             Syria                          NaN
# 143                            Taiwan                          NaN
#
#                country_origin                           country 2021-country
# 6    Central African Republic          Central African Republic          NaN
# 8            Congo (Kinshasa)  Democratic Republic of the Congo          NaN
# 16                    Somalia                           Somalia          NaN
# 37                     Bhutan                            Bhutan          NaN
# 119         Trinidad & Tobago               Trinidad and Tobago          NaN
# 131               South Sudan                             Sudan          NaN
# 140                     Qatar                             Qatar          NaN
# 142                     Syria                             Syria          NaN
# 143                    Taiwan                            Taiwan          NaN

# %%
col = "2022-country"
diff = df_origine_light_completed2[df_origine_light_completed2[col] != df_origine_light_completed2["country"]]
diff = diff[['country_official', 'Regional indicator', 'country_origin','country', col ]]
diff
# Out:
#                      country_official           Regional indicator  \
# 6            Central African Republic           Sub-Saharan Africa
# 8    Democratic Republic Of The Congo           Sub-Saharan Africa
# 16        Federal Republic of Somalia                          NaN
# 37                  Kingdom of Bhutan                          NaN
# 72                Republic of Burundi           Sub-Saharan Africa
# 87                  Republic of Haiti  Latin America and Caribbean
# 157              Republic of Maldives                   South Asia
# 119   Republic of Trinidad and Tobago  Latin America and Caribbean
# 127             Republic of the Congo           Sub-Saharan Africa
# 131             Republic of the Sudan           Sub-Saharan Africa
# 140                    State of Qatar                          NaN
# 142                             Syria                          NaN
# 143                            Taiwan                          NaN
#
#                country_origin                           country 2022-country
# 6    Central African Republic          Central African Republic          NaN
# 8            Congo (Kinshasa)  Democratic Republic of the Congo          NaN
# 16                    Somalia                           Somalia          NaN
# 37                     Bhutan                            Bhutan          NaN
# 72                    Burundi                           Burundi          NaN
# 87                      Haiti                             Haiti          NaN
# 157                  Maldives                          Maldives          NaN
# 119         Trinidad & Tobago               Trinidad and Tobago          NaN
# 127       Congo (Brazzaville)             Republic of the Congo        Congo
# 131               South Sudan                             Sudan          NaN
# 140                     Qatar                             Qatar          NaN
# 142                     Syria                             Syria          NaN
# 143                    Taiwan                            Taiwan          NaN

# %%
df_origine_light_completed2[df_origine_light_completed2["country_origin"]!=df_origine_light_completed2["country"]]
# Out:
#                                      country_official  \
# 8                    Democratic Republic Of The Congo
# 24   Hong Kong Special Administrative Region of China
# 40                                Kingdom of Eswatini
# 156                                 Republic of China
# 119                   Republic of Trinidad and Tobago
# 127                             Republic of the Congo
# 131                             Republic of the Sudan
#
#               Regional indicator            country_origin  \
# 8             Sub-Saharan Africa          Congo (Kinshasa)
# 24                     East Asia                 Hong Kong
# 40            Sub-Saharan Africa                 Swaziland
# 156                    East Asia  Taiwan Province of China
# 119  Latin America and Caribbean         Trinidad & Tobago
# 127           Sub-Saharan Africa       Congo (Brazzaville)
# 131           Sub-Saharan Africa               South Sudan
#
#                               country  2019-rank   2022   2021   2020   2019  \
# 8    Democratic Republic of the Congo      127.0    NaN    NaN  4.311  4.418
# 24          Hong Kong S.A.R. of China       76.0  5.425  5.477  5.510  5.430
# 40                           Eswatini      135.0  4.396  4.308  4.308  4.212
# 156                 Republic of China        NaN  6.512  6.584  6.455    NaN
# 119               Trinidad and Tobago       39.0    NaN    NaN  6.192  6.192
# 127             Republic of the Congo      103.0  5.075  5.342  5.194  4.812
# 131                             Sudan      156.0    NaN    NaN  2.817  2.853
#
#      2019-PIB  ...  2022-rank  2022-Whisker-high  2022-Whisker-low  \
# 8       0.094  ...        NaN                NaN               NaN
# 24      1.438  ...       81.0              5.501             5.348
# 40      0.811  ...      125.0              4.607             4.185
# 156       NaN  ...       26.0              6.596             6.429
# 119     1.231  ...        NaN                NaN               NaN
# 127     0.673  ...       99.0              5.235             4.915
# 131     0.306  ...        NaN                NaN               NaN
#
#      2022-Dystopia + residual  2022-PIB  2022-Soutien  2022-Esperance vie BS  \
# 8                         NaN       NaN           NaN                    NaN
# 24                      0.642     1.957         0.954                  0.942
# 40                      1.688     1.274         0.786                  0.197
# 156                     2.002     1.897         1.095                  0.733
# 119                       NaN       NaN           NaN                    NaN
# 127                     2.658     0.950         0.405                  0.355
# 131                       NaN       NaN           NaN                    NaN
#
#      2022-Liberte des choix de vie  2022-Generosite  2022-Corruption
# 8                              NaN              NaN              NaN
# 24                           0.400            0.147            0.383
# 40                           0.259            0.038            0.154
# 156                          0.542            0.075            0.168
# 119                            NaN              NaN              NaN
# 127                          0.431            0.130            0.146
# 131                            NaN              NaN              NaN
#
# [7 rows x 43 columns]

# %% [markdown]
# <div style="display: flex; background-color: Green; padding: 7px;" >
#
# ### Nettoyage des données suite fusion avec les fichiers d'évolution des scores par année
# </div>

# %%
col1 = '2019'
col2 = 'score_'+col1

diff = df_light_merged[(df_light_merged[col1] != df_light_merged[col2]) & (df_light_merged[col2].notna()) & (df_light_merged[col1].notna())]
print(diff.shape)
diff[['country_official', 'country_origin', 'Regional indicator',
       'country_FR', col1, col2,'_merge']]
# Out:
# (3, 50)
#           country_official       country_origin            Regional indicator  \
# 131  Republic of the Congo  Congo (Brazzaville)            Sub-Saharan Africa
# 140        Slovak Republic             Slovakia    Central and Eastern Europe
# 143        State of Kuwait               Kuwait  Middle East and North Africa
#
#       country_FR   2019  score_2019 _merge
# 131  Congo (RDC)  4.812       4.418   both
# 140     Slovénie  6.198       6.118   both
# 143       Koweït  6.021       6.011   both

# %%
col1 = '2020'
col2 = 'score_'+col1

diff = df_light_merged[(df_light_merged[col1] != df_light_merged[col2]) & (df_light_merged[col2].notna()) & (df_light_merged[col1].notna())]
print(diff.shape)
diff[['country_official', 'country_origin', 'Regional indicator',
       'country_FR', col1, col2,'_merge']]
# Out:
# (2, 50)
#           country_official       country_origin          Regional indicator  \
# 131  Republic of the Congo  Congo (Brazzaville)          Sub-Saharan Africa
# 140        Slovak Republic             Slovakia  Central and Eastern Europe
#
#       country_FR   2020  score_2020 _merge
# 131  Congo (RDC)  5.194       4.311   both
# 140     Slovénie  6.281       6.363   both
